# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !nvidia-smi
# Out:
# Wed May 20 03:05:08 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers==0.7.0 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.90)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.4)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.15.0)
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.6/dist-packages (0.7.6)
# Requirement already satisfied: pyyaml>=3.13 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (3.13)
# Requirement already satisfied: torch>=1.1 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (1.5.0+cu101)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (1.18.4)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (0.18.2)
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (2.2.1)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.6/dist-packages (from pytorch_lightning) (4.41.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (3.2.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (1.29.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (1.12.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (0.9.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (1.0.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (0.34.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (1.7.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (1.6.0.post3)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (3.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->pytorch_lightning) (46.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard>=1.14->pytorch_lightning) (1.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning) (2020.4.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning) (4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch_lightning) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->pytorch_lightning) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch_lightning) (3.1.0)

# %% [markdown]
# ## T5 fine-tuning
#
# This notebook is to showcase how to fine-tune [T5 model](https://arxiv.org/abs/1910.10683) with Huggigface's [Transformers](https://github.com/huggingface/transformers/) to solve different NLP tasks using text-2-text approach proposed in the T5 paper. For demo I chose 3 non text-2-text problems just to reiterate the fact from the paper that how widely applicable this text-2-text framework is and how it can be used for different tasks without changing the model at all.

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
from itertools import chain
from string import punctuation

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# ## Model
#
# We'll be using the awesome [pytorch-lightning](https://github.com/PytorchLightning/pytorch-lightning) library for training. Most of the below code is adapted from here https://github.com/huggingface/transformers/blob/master/examples/lightning_base.py
#
# The trainer is generic and can be used for any text-2-text task. You'll just need to change the dataset. Rest of the code will stay unchanged for all the tasks.
#
# This is the most intresting and powrfull thing about the text-2-text format. You can fine-tune the model on variety of NLP tasks by just formulating the problem in text-2-text setting. No need to change hyperparameters, learning rate, optimizer or loss function. Just plug in your dataset and you are ready to go!

# %%
class T5FineTuner(pl.LightningModule):
  def __init__(self, hparams):
    super(T5FineTuner, self).__init__()
    self.hparams = hparams
    
    self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
    self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)
  
  def is_logger(self):
    return self.trainer.proc_rank <= 0
  
  def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, lm_labels=None
  ):
    return self.model(
        input_ids,
        attention_mask=attention_mask,
        decoder_input_ids=decoder_input_ids,
        decoder_attention_mask=decoder_attention_mask,
        lm_labels=lm_labels,
    )

  def _step(self, batch):
    lm_labels = batch["target_ids"]
    lm_labels[lm_labels[:, :] == self.tokenizer.pad_token_id] = -100

    outputs = self(
        input_ids=batch["source_ids"],
        attention_mask=batch["source_mask"],
        lm_labels=lm_labels,
        decoder_attention_mask=batch['target_mask']
    )

    loss = outputs[0]

    return loss

  def training_step(self, batch, batch_idx):
    loss = self._step(batch)

    tensorboard_logs = {"train_loss": loss}
    return {"loss": loss, "log": tensorboard_logs}
  
  def training_epoch_end(self, outputs):
    avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
    tensorboard_logs = {"avg_train_loss": avg_train_loss}
    return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def validation_step(self, batch, batch_idx):
    loss = self._step(batch)
    return {"val_loss": loss}
  
  def validation_epoch_end(self, outputs):
    avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
    tensorboard_logs = {"val_loss": avg_loss}
    return {"avg_val_loss": avg_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def configure_optimizers(self):
    "Prepare optimizer and schedule (linear warmup and decay)"

    model = self.model
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": self.hparams.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
    self.opt = optimizer
    return [optimizer]
  
  def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure=None):
    if self.trainer.use_tpu:
      xm.optimizer_step(optimizer)
    else:
      optimizer.step()
    optimizer.zero_grad()
    self.lr_scheduler.step()
  
  def get_tqdm_dict(self):
    tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

    return tqdm_dict

  def train_dataloader(self):
    train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
    dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
    t_total = (
        (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
        // self.hparams.gradient_accumulation_steps
        * float(self.hparams.num_train_epochs)
    )
    scheduler = get_linear_schedule_with_warmup(
        self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
    )
    self.lr_scheduler = scheduler
    return dataloader

  def val_dataloader(self):
    val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
    return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %%
logger = logging.getLogger(__name__)

class LoggingCallback(pl.Callback):
  def on_validation_end(self, trainer, pl_module):
    logger.info("***** Validation results *****")
    if pl_module.is_logger():
      metrics = trainer.callback_metrics
      # Log results
      for key in sorted(metrics):
        if key not in ["log", "progress_bar"]:
          logger.info("{} = {}\n".format(key, str(metrics[key])))

  def on_test_end(self, trainer, pl_module):
    logger.info("***** Test results *****")

    if pl_module.is_logger():
      metrics = trainer.callback_metrics

      # Log and save results to file
      output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
      with open(output_test_results_file, "w") as writer:
        for key in sorted(metrics):
          if key not in ["log", "progress_bar"]:
            logger.info("{} = {}\n".format(key, str(metrics[key])))
            writer.write("{} = {}\n".format(key, str(metrics[key])))

# %% [markdown]
# Let's define the hyperparameters and other arguments. You can overide this dict for specific task as needed. While in most of cases you'll only need to change the data_dirand output_dir.
#
# Here the batch size is 8 and gradient_accumulation_steps are 16 so the effective batch size is 128

# %%
args_dict = dict(
    data_dir="", # path for data files
    output_dir="", # path to save the checkpoints
    model_name_or_path='t5-base',
    tokenizer_name_or_path='t5-base',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=2,
    eval_batch_size=2,
    num_train_epochs=1,
    gradient_accumulation_steps=16,
    n_gpu=1,
    early_stop_callback=False,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %% [markdown]
# # T5 Finetuning for Question Generation
#
# We are gonna process the dataset from SQUAD for training Question Generation with consist of 100k question and that would be

# %%
# !mkdir squad
# !cp /content/drive/My\ Drive/SQUAD/*.csv squad
# Out:
# mkdir: cannot create directory ‘squad’: File exists
# cp: cannot stat '/content/drive/My Drive/SQUAD/*.csv': Transport endpoint is not connected

# %%
train_df = pd.read_csv("/content/squad/train.csv")

# %%
train_df.columns
# Out:
# Index(['id', 'context', 'question', 'answer_start', 'text'], dtype='object')

# %%
import csv
from dataclasses import dataclass

from enum import Enum
from typing import List, Optional
from transformers import PreTrainedTokenizer

# %% [markdown]
#   example_id : str
#   text : str
#   selected_text : str
#   sentiment : str

# %%
@dataclass(frozen=True)
class InputExample:
  example_id : str
  context : str
  answer : str
  label : str
  """
    A single training/test example for multiple choice
    Args:
        example_id: Unique id for the example.
        contexts: list of str. The untokenized text of the first sequence (context of corresponding question).
        answer : str containing answer for which we need to generate question
        label: string containg questions
    """


class Split(Enum):
    train = "train"
    dev = "dev"
    test = "test"

class DataProcessor:
    """Base class for data converters for multiple choice data sets."""

    def get_train_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the train set."""
        raise NotImplementedError()

    def get_dev_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the dev set."""
        raise NotImplementedError()

    def get_test_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the test set."""
        raise NotImplementedError()

    def get_labels(self):
        """Gets the list of labels for this data set."""
        raise NotImplementedError()

class SwagProcessor(DataProcessor):
    """Processor for the SWAG data set."""

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "train.csv")), "train")

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "val.csv")), "dev")

    def get_test_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        raise ValueError(
            "For swag testing, the input file does not contain a label column. It can not be tested in current code"
            "setting!"
        )
        return self._create_examples(self._read_csv(os.path.join(data_dir, "test.csv")), "test")

    

    def _read_csv(self, input_file):
        with open(input_file, "r", encoding="utf-8") as f:
            return list(csv.reader(f))

    def _create_examples(self, lines: List[List[str]], type: str):
        """Creates examples for the training and dev sets."""
        if type == "train" and lines[0][2] != "question":
            raise ValueError("For training, the input file must contain a label column.")

        examples = [
            InputExample(
                example_id=line[0],
                # common beginning of each
                # choice is stored in "sent2".
                context=line[1],
                answer=line[4],
                label=line[2],
            )
            for line in lines[1:]  # we skip the line with the column names
        ]

        return examples

# %% [markdown]
# Index(['id', 'context', 'question', 'answer_start', 'text'], dtype='object')

# %%
class SquadDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.data_dir = data_dir
    self.type_path = type_path
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self.proc = SwagProcessor()

    self._build()
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def __len__(self):
    return len(self.inputs)
  
  def _build(self):
    if self.type_path == 'train':
      examples = self.proc.get_train_examples(self.data_dir)
    else:
      examples = self.proc.get_dev_examples(self.data_dir)
    
    for example in examples:
      self._create_features(example)
  
  def _create_features(self, example):
    input_ = example.context
    answer = example.answer
    input_ = "context: %s  answer: %s </s>" % (input_, answer)
    target = example.label
    target = "question: %s </s>" % (str(target))

    # tokenize inputs
    tokenized_inputs = self.tokenizer.batch_encode_plus(
        [input_], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
    )
    # tokenize targets
    tokenized_targets = self.tokenizer.batch_encode_plus(
        [target], max_length=200, pad_to_max_length=True, return_tensors="pt"
    )

    self.inputs.append(tokenized_inputs)
    self.targets.append(tokenized_targets)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')

# %%
dataset = SquadDataset(tokenizer, data_dir='squad', type_path='val')
len(dataset)
# Out:
# 10388

# %%
data = dataset[69]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# context: None of the original treaties establishing the European Union mention protection for fundamental rights. It was not envisaged for European Union measures, that is legislative and administrative actions by European Union institutions, to be subject to human rights. At the time the only concern was that member states should be prevented from violating human rights, hence the establishment of the European Convention on Human Rights in 1950 and the establishment of the European Court of Human Rights. The European Court of Justice recognised fundamental rights as general principle of European Union law as the need to ensure that European Union measures are compatible with the human rights enshrined in member states' constitution became ever more apparent. In 1999 the European Council set up a body tasked with drafting a European Charter of Human Rights, which could form the constitutional basis for the European Union and as such tailored specifically to apply to the European Union and its institutions. The Charter of Fundamental Rights of the European Union draws a list of fundamental rights from the European Convention on Human Rights and Fundamental Freedoms, the Declaration on Fundamental Rights produced by the European Parliament in 1989 and European Union Treaties. answer: the European Convention on Human Rights in 1950 and the establishment of the European Court of Human Rights
# question: Which entities were originally concerned with preventing violation of human rights?

# %%
# !mkdir -p t5_squad
args_dict.update({'data_dir': 'squad', 'output_dir': 't5_squad', 'num_train_epochs': 1})
args = argparse.Namespace(**args_dict)
print(args_dict)
# Out:
# {'data_dir': 'squad', 'output_dir': 't5_squad', 'model_name_or_path': 't5-base', 'tokenizer_name_or_path': 't5-base', 'max_seq_length': 512, 'learning_rate': 0.0003, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'warmup_steps': 0, 'train_batch_size': 2, 'eval_batch_size': 2, 'num_train_epochs': 1, 'gradient_accumulation_steps': 16, 'n_gpu': 1, 'early_stop_callback': False, 'fp_16': False, 'opt_level': 'O1', 'max_grad_norm': 1.0, 'seed': 42}

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return SquadDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)

# %%
trainer = pl.Trainer(**train_params)
# Out:
# GPU available: True, used: True
# No environment variable for node rank defined. Set as 0.
# CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
#     | Name                                                                  | Type                       | Params
# -----------------------------------------------------------------------------------------------------------------
# 0   | model                                                                 | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                          | Embedding                  | 24 M
# 2   | model.encoder                                                         | T5Stack                    | 109 M
# 3   | model.encoder.block                                                   | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                                 | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                           | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                         | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 21  | model.encoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 22  | model.encoder.block.1                                                 | T5Block                    | 7 M
# 23  | model.encoder.block.1.layer                                           | ModuleList                 | 7 M
# 24  | model.encoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 25  | model.encoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 27  | model.encoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 31  | model.encoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 32  | model.encoder.block.1.layer.1                                         | T5LayerFF                  | 4 M
# 33  | model.encoder.block.1.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 37  | model.encoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 38  | model.encoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 39  | model.encoder.block.2                                                 | T5Block                    | 7 M
# 40  | model.encoder.block.2.layer                                           | ModuleList                 | 7 M
# 41  | model.encoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 42  | model.encoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 43  | model.encoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 44  | model.encoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 45  | model.encoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 48  | model.encoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 49  | model.encoder.block.2.layer.1                                         | T5LayerFF                  | 4 M
# 50  | model.encoder.block.2.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 51  | model.encoder.block.2.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 54  | model.encoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 55  | model.encoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 56  | model.encoder.block.3                                                 | T5Block                    | 7 M
# 57  | model.encoder.block.3.layer                                           | ModuleList                 | 7 M
# 58  | model.encoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 59  | model.encoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 60  | model.encoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 61  | model.encoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 62  | model.encoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 63  | model.encoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 65  | model.encoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 66  | model.encoder.block.3.layer.1                                         | T5LayerFF                  | 4 M
# 67  | model.encoder.block.3.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 68  | model.encoder.block.3.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 69  | model.encoder.block.3.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 71  | model.encoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 72  | model.encoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 73  | model.encoder.block.4                                                 | T5Block                    | 7 M
# 74  | model.encoder.block.4.layer                                           | ModuleList                 | 7 M
# 75  | model.encoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 76  | model.encoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 77  | model.encoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 78  | model.encoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 79  | model.encoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 80  | model.encoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 81  | model.encoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 82  | model.encoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 83  | model.encoder.block.4.layer.1                                         | T5LayerFF                  | 4 M
# 84  | model.encoder.block.4.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 85  | model.encoder.block.4.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 86  | model.encoder.block.4.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 87  | model.encoder.block.4.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 88  | model.encoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 89  | model.encoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 90  | model.encoder.block.5                                                 | T5Block                    | 7 M
# 91  | model.encoder.block.5.layer                                           | ModuleList                 | 7 M
# 92  | model.encoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 93  | model.encoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 94  | model.encoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 95  | model.encoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 96  | model.encoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 97  | model.encoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 98  | model.encoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 99  | model.encoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 100 | model.encoder.block.5.layer.1                                         | T5LayerFF                  | 4 M
# 101 | model.encoder.block.5.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 102 | model.encoder.block.5.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 103 | model.encoder.block.5.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 104 | model.encoder.block.5.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 106 | model.encoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 107 | model.encoder.block.6                                                 | T5Block                    | 7 M
# 108 | model.encoder.block.6.layer                                           | ModuleList                 | 7 M
# 109 | model.encoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 110 | model.encoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 111 | model.encoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 112 | model.encoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 113 | model.encoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 114 | model.encoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 115 | model.encoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 116 | model.encoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 117 | model.encoder.block.6.layer.1                                         | T5LayerFF                  | 4 M
# 118 | model.encoder.block.6.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 119 | model.encoder.block.6.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 120 | model.encoder.block.6.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 121 | model.encoder.block.6.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 122 | model.encoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 123 | model.encoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 124 | model.encoder.block.7                                                 | T5Block                    | 7 M
# 125 | model.encoder.block.7.layer                                           | ModuleList                 | 7 M
# 126 | model.encoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 127 | model.encoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 128 | model.encoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 129 | model.encoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 130 | model.encoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 131 | model.encoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 132 | model.encoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 133 | model.encoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 134 | model.encoder.block.7.layer.1                                         | T5LayerFF                  | 4 M
# 135 | model.encoder.block.7.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 136 | model.encoder.block.7.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 137 | model.encoder.block.7.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 138 | model.encoder.block.7.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 139 | model.encoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 141 | model.encoder.block.8                                                 | T5Block                    | 7 M
# 142 | model.encoder.block.8.layer                                           | ModuleList                 | 7 M
# 143 | model.encoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 144 | model.encoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 145 | model.encoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 146 | model.encoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 147 | model.encoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 148 | model.encoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 149 | model.encoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 150 | model.encoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 151 | model.encoder.block.8.layer.1                                         | T5LayerFF                  | 4 M
# 152 | model.encoder.block.8.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 153 | model.encoder.block.8.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 154 | model.encoder.block.8.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 155 | model.encoder.block.8.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 156 | model.encoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 157 | model.encoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 158 | model.encoder.block.9                                                 | T5Block                    | 7 M
# 159 | model.encoder.block.9.layer                                           | ModuleList                 | 7 M
# 160 | model.encoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 161 | model.encoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 162 | model.encoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 163 | model.encoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 164 | model.encoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 165 | model.encoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 166 | model.encoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 167 | model.encoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 168 | model.encoder.block.9.layer.1                                         | T5LayerFF                  | 4 M
# 169 | model.encoder.block.9.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 170 | model.encoder.block.9.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 171 | model.encoder.block.9.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 172 | model.encoder.block.9.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 173 | model.encoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 174 | model.encoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 175 | model.encoder.block.10                                                | T5Block                    | 7 M
# 176 | model.encoder.block.10.layer                                          | ModuleList                 | 7 M
# 177 | model.encoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 178 | model.encoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 179 | model.encoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 180 | model.encoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 181 | model.encoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 182 | model.encoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 183 | model.encoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 184 | model.encoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 185 | model.encoder.block.10.layer.1                                        | T5LayerFF                  | 4 M
# 186 | model.encoder.block.10.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 187 | model.encoder.block.10.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 188 | model.encoder.block.10.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 189 | model.encoder.block.10.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 190 | model.encoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 191 | model.encoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 192 | model.encoder.block.11                                                | T5Block                    | 7 M
# 193 | model.encoder.block.11.layer                                          | ModuleList                 | 7 M
# 194 | model.encoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 195 | model.encoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 196 | model.encoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 197 | model.encoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 198 | model.encoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 199 | model.encoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 200 | model.encoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 201 | model.encoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 202 | model.encoder.block.11.layer.1                                        | T5LayerFF                  | 4 M
# 203 | model.encoder.block.11.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 204 | model.encoder.block.11.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 205 | model.encoder.block.11.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 206 | model.encoder.block.11.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 207 | model.encoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 208 | model.encoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 209 | model.encoder.final_layer_norm                                        | T5LayerNorm                | 768
# 210 | model.encoder.dropout                                                 | Dropout                    | 0
# 211 | model.decoder                                                         | T5Stack                    | 137 M
# 212 | model.decoder.block                                                   | ModuleList                 | 113 M
# 213 | model.decoder.block.0                                                 | T5Block                    | 9 M
# 214 | model.decoder.block.0.layer                                           | ModuleList                 | 9 M
# 215 | model.decoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 216 | model.decoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 217 | model.decoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 218 | model.decoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 219 | model.decoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 220 | model.decoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 221 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 222 | model.decoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 223 | model.decoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 224 | model.decoder.block.0.layer.1                                         | T5LayerCrossAttention      | 2 M
# 225 | model.decoder.block.0.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 226 | model.decoder.block.0.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 227 | model.decoder.block.0.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 228 | model.decoder.block.0.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 229 | model.decoder.block.0.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.1.EncDecAttention.relative_attention_bias | Embedding                  | 384
# 231 | model.decoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 232 | model.decoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 233 | model.decoder.block.0.layer.2                                         | T5LayerFF                  | 4 M
# 234 | model.decoder.block.0.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 235 | model.decoder.block.0.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 236 | model.decoder.block.0.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 237 | model.decoder.block.0.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 238 | model.decoder.block.0.layer.2.layer_norm                              | T5LayerNorm                | 768
# 239 | model.decoder.block.0.layer.2.dropout                                 | Dropout                    | 0
# 240 | model.decoder.block.1                                                 | T5Block                    | 9 M
# 241 | model.decoder.block.1.layer                                           | ModuleList                 | 9 M
# 242 | model.decoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 243 | model.decoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 244 | model.decoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 245 | model.decoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 246 | model.decoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 247 | model.decoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 248 | model.decoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 249 | model.decoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 250 | model.decoder.block.1.layer.1                                         | T5LayerCrossAttention      | 2 M
# 251 | model.decoder.block.1.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 252 | model.decoder.block.1.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 253 | model.decoder.block.1.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 254 | model.decoder.block.1.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 255 | model.decoder.block.1.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 256 | model.decoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 257 | model.decoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 258 | model.decoder.block.1.layer.2                                         | T5LayerFF                  | 4 M
# 259 | model.decoder.block.1.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 260 | model.decoder.block.1.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 261 | model.decoder.block.1.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 262 | model.decoder.block.1.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 263 | model.decoder.block.1.layer.2.layer_norm                              | T5LayerNorm                | 768
# 264 | model.decoder.block.1.layer.2.dropout                                 | Dropout                    | 0
# 265 | model.decoder.block.2                                                 | T5Block                    | 9 M
# 266 | model.decoder.block.2.layer                                           | ModuleList                 | 9 M
# 267 | model.decoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 268 | model.decoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 269 | model.decoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 270 | model.decoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 271 | model.decoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 272 | model.decoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 273 | model.decoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 274 | model.decoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 275 | model.decoder.block.2.layer.1                                         | T5LayerCrossAttention      | 2 M
# 276 | model.decoder.block.2.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 277 | model.decoder.block.2.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 278 | model.decoder.block.2.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 279 | model.decoder.block.2.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 280 | model.decoder.block.2.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 281 | model.decoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 282 | model.decoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 283 | model.decoder.block.2.layer.2                                         | T5LayerFF                  | 4 M
# 284 | model.decoder.block.2.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 285 | model.decoder.block.2.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 286 | model.decoder.block.2.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 287 | model.decoder.block.2.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 288 | model.decoder.block.2.layer.2.layer_norm                              | T5LayerNorm                | 768
# 289 | model.decoder.block.2.layer.2.dropout                                 | Dropout                    | 0
# 290 | model.decoder.block.3                                                 | T5Block                    | 9 M
# 291 | model.decoder.block.3.layer                                           | ModuleList                 | 9 M
# 292 | model.decoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 293 | model.decoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 294 | model.decoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 295 | model.decoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 296 | model.decoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 297 | model.decoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 298 | model.decoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 299 | model.decoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 300 | model.decoder.block.3.layer.1                                         | T5LayerCrossAttention      | 2 M
# 301 | model.decoder.block.3.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 302 | model.decoder.block.3.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 303 | model.decoder.block.3.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 304 | model.decoder.block.3.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 305 | model.decoder.block.3.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 306 | model.decoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 307 | model.decoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 308 | model.decoder.block.3.layer.2                                         | T5LayerFF                  | 4 M
# 309 | model.decoder.block.3.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 310 | model.decoder.block.3.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 311 | model.decoder.block.3.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 312 | model.decoder.block.3.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 313 | model.decoder.block.3.layer.2.layer_norm                              | T5LayerNorm                | 768
# 314 | model.decoder.block.3.layer.2.dropout                                 | Dropout                    | 0
# 315 | model.decoder.block.4                                                 | T5Block                    | 9 M
# 316 | model.decoder.block.4.layer                                           | ModuleList                 | 9 M
# 317 | model.decoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 318 | model.decoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 319 | model.decoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 320 | model.decoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 321 | model.decoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 322 | model.decoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 323 | model.decoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 324 | model.decoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 325 | model.decoder.block.4.layer.1                                         | T5LayerCrossAttention      | 2 M
# 326 | model.decoder.block.4.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 327 | model.decoder.block.4.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 328 | model.decoder.block.4.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 329 | model.decoder.block.4.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 330 | model.decoder.block.4.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 331 | model.decoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 332 | model.decoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 333 | model.decoder.block.4.layer.2                                         | T5LayerFF                  | 4 M
# 334 | model.decoder.block.4.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 335 | model.decoder.block.4.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 336 | model.decoder.block.4.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 337 | model.decoder.block.4.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 338 | model.decoder.block.4.layer.2.layer_norm                              | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.2.dropout                                 | Dropout                    | 0
# 340 | model.decoder.block.5                                                 | T5Block                    | 9 M
# 341 | model.decoder.block.5.layer                                           | ModuleList                 | 9 M
# 342 | model.decoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 343 | model.decoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 344 | model.decoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 345 | model.decoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 346 | model.decoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 347 | model.decoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 348 | model.decoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 349 | model.decoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 350 | model.decoder.block.5.layer.1                                         | T5LayerCrossAttention      | 2 M
# 351 | model.decoder.block.5.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 352 | model.decoder.block.5.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 353 | model.decoder.block.5.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 354 | model.decoder.block.5.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 355 | model.decoder.block.5.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 356 | model.decoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 357 | model.decoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 358 | model.decoder.block.5.layer.2                                         | T5LayerFF                  | 4 M
# 359 | model.decoder.block.5.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 360 | model.decoder.block.5.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 361 | model.decoder.block.5.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 362 | model.decoder.block.5.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 363 | model.decoder.block.5.layer.2.layer_norm                              | T5LayerNorm                | 768
# 364 | model.decoder.block.5.layer.2.dropout                                 | Dropout                    | 0
# 365 | model.decoder.block.6                                                 | T5Block                    | 9 M
# 366 | model.decoder.block.6.layer                                           | ModuleList                 | 9 M
# 367 | model.decoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 368 | model.decoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 369 | model.decoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 370 | model.decoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 371 | model.decoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 372 | model.decoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 373 | model.decoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 374 | model.decoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 375 | model.decoder.block.6.layer.1                                         | T5LayerCrossAttention      | 2 M
# 376 | model.decoder.block.6.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 377 | model.decoder.block.6.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 378 | model.decoder.block.6.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 379 | model.decoder.block.6.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 380 | model.decoder.block.6.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 381 | model.decoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 382 | model.decoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 383 | model.decoder.block.6.layer.2                                         | T5LayerFF                  | 4 M
# 384 | model.decoder.block.6.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 385 | model.decoder.block.6.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 386 | model.decoder.block.6.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 387 | model.decoder.block.6.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 388 | model.decoder.block.6.layer.2.layer_norm                              | T5LayerNorm                | 768
# 389 | model.decoder.block.6.layer.2.dropout                                 | Dropout                    | 0
# 390 | model.decoder.block.7                                                 | T5Block                    | 9 M
# 391 | model.decoder.block.7.layer                                           | ModuleList                 | 9 M
# 392 | model.decoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 393 | model.decoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 394 | model.decoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 395 | model.decoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 396 | model.decoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 397 | model.decoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 398 | model.decoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 399 | model.decoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 400 | model.decoder.block.7.layer.1                                         | T5LayerCrossAttention      | 2 M
# 401 | model.decoder.block.7.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 402 | model.decoder.block.7.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 403 | model.decoder.block.7.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 404 | model.decoder.block.7.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 405 | model.decoder.block.7.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 406 | model.decoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 407 | model.decoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 408 | model.decoder.block.7.layer.2                                         | T5LayerFF                  | 4 M
# 409 | model.decoder.block.7.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 410 | model.decoder.block.7.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 411 | model.decoder.block.7.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 412 | model.decoder.block.7.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 413 | model.decoder.block.7.layer.2.layer_norm                              | T5LayerNorm                | 768
# 414 | model.decoder.block.7.layer.2.dropout                                 | Dropout                    | 0
# 415 | model.decoder.block.8                                                 | T5Block                    | 9 M
# 416 | model.decoder.block.8.layer                                           | ModuleList                 | 9 M
# 417 | model.decoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 418 | model.decoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 419 | model.decoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 420 | model.decoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 421 | model.decoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 422 | model.decoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 423 | model.decoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 424 | model.decoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 425 | model.decoder.block.8.layer.1                                         | T5LayerCrossAttention      | 2 M
# 426 | model.decoder.block.8.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 427 | model.decoder.block.8.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 428 | model.decoder.block.8.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 429 | model.decoder.block.8.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 430 | model.decoder.block.8.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 431 | model.decoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 432 | model.decoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 433 | model.decoder.block.8.layer.2                                         | T5LayerFF                  | 4 M
# 434 | model.decoder.block.8.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 435 | model.decoder.block.8.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 436 | model.decoder.block.8.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 437 | model.decoder.block.8.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 438 | model.decoder.block.8.layer.2.layer_norm                              | T5LayerNorm                | 768
# 439 | model.decoder.block.8.layer.2.dropout                                 | Dropout                    | 0
# 440 | model.decoder.block.9                                                 | T5Block                    | 9 M
# 441 | model.decoder.block.9.layer                                           | ModuleList                 | 9 M
# 442 | model.decoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 443 | model.decoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 444 | model.decoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 445 | model.decoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 446 | model.decoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 447 | model.decoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 448 | model.decoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 449 | model.decoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 450 | model.decoder.block.9.layer.1                                         | T5LayerCrossAttention      | 2 M
# 451 | model.decoder.block.9.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 452 | model.decoder.block.9.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 453 | model.decoder.block.9.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 454 | model.decoder.block.9.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 455 | model.decoder.block.9.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 456 | model.decoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 457 | model.decoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 458 | model.decoder.block.9.layer.2                                         | T5LayerFF                  | 4 M
# 459 | model.decoder.block.9.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 460 | model.decoder.block.9.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 461 | model.decoder.block.9.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 462 | model.decoder.block.9.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 463 | model.decoder.block.9.layer.2.layer_norm                              | T5LayerNorm                | 768
# 464 | model.decoder.block.9.layer.2.dropout                                 | Dropout                    | 0
# 465 | model.decoder.block.10                                                | T5Block                    | 9 M
# 466 | model.decoder.block.10.layer                                          | ModuleList                 | 9 M
# 467 | model.decoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 468 | model.decoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 469 | model.decoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 470 | model.decoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 471 | model.decoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 472 | model.decoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 473 | model.decoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 474 | model.decoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 475 | model.decoder.block.10.layer.1                                        | T5LayerCrossAttention      | 2 M
# 476 | model.decoder.block.10.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 477 | model.decoder.block.10.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 478 | model.decoder.block.10.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 479 | model.decoder.block.10.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 480 | model.decoder.block.10.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 481 | model.decoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 482 | model.decoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 483 | model.decoder.block.10.layer.2                                        | T5LayerFF                  | 4 M
# 484 | model.decoder.block.10.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 485 | model.decoder.block.10.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 486 | model.decoder.block.10.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 487 | model.decoder.block.10.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 488 | model.decoder.block.10.layer.2.layer_norm                             | T5LayerNorm                | 768
# 489 | model.decoder.block.10.layer.2.dropout                                | Dropout                    | 0
# 490 | model.decoder.block.11                                                | T5Block                    | 9 M
# 491 | model.decoder.block.11.layer                                          | ModuleList                 | 9 M
# 492 | model.decoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 493 | model.decoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 494 | model.decoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 495 | model.decoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 496 | model.decoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 497 | model.decoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 498 | model.decoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 499 | model.decoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 500 | model.decoder.block.11.layer.1                                        | T5LayerCrossAttention      | 2 M
# 501 | model.decoder.block.11.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 502 | model.decoder.block.11.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 503 | model.decoder.block.11.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 504 | model.decoder.block.11.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 505 | model.decoder.block.11.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 506 | model.decoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 507 | model.decoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 508 | model.decoder.block.11.layer.2                                        | T5LayerFF                  | 4 M
# 509 | model.decoder.block.11.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 510 | model.decoder.block.11.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 511 | model.decoder.block.11.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 512 | model.decoder.block.11.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 513 | model.decoder.block.11.layer.2.layer_norm                             | T5LayerNorm                | 768
# 514 | model.decoder.block.11.layer.2.dropout                                | Dropout                    | 0
# 515 | model.decoder.final_layer_norm                                        | T5LayerNorm                | 768
# 516 | model.decoder.dropout                                                 | Dropout                    | 0
# 517 | model.lm_head                                                         | Linear                     | 24 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# 1

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset =  SquadDataset(tokenizer, data_dir='squad', type_path='val')
loader = DataLoader(dataset, batch_size=32, num_workers=4)

# %%
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=200)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=325.0), HTML(value='')))

# %%
outputs
# Out:
# ['question: How many gasoline stations in the United States had no fuel in the last week of February 1974?',
#  'question: What is the restriction modification system called?',
#  'question: What team was suspended after the 2014 season?',
#  'question: What area is Dyrrachium located in?',
#  'question: What promoted trade between East and West?',
#  'question: What determines the split of particles?',
#  'question: What was the name of the emperors of the Yuan Empire?',
#  'question: What is acetone?',
#  'question: What is a hermaphrodite?',
#  'question: What components are determined by the scalar addition of the components of the individual vectors?',
#  'question: Who was the commander of the Virginia Regiment?',
#  'question: Who succeeded Marin as commander of the French forces?',
#  'question: What does the network guarantee in the virtual call system?',
#  'question: How much dust falls over the Amazon basin?',
#  'question: When did OPEC issue a joint communiqué?',
#  'question: What is the local pronunciation of Donkey?',
#  'question: What did the Islamic Jihad believe leaders did?',
#  'question: What percentage of private students attend Catholic schools?',
#  'question: What concept did Baran develop during his research?',
#  'question: In what year was Harvard College renamed Harvard College?',
#  'question: What type of surveys do stratigraphers analyze data from?',
#  'question: What type of rift system did the Alpine orogeny cause?',
#  'question: What are some of the conditions that contributed to the severity of the Black Death?',
#  "question: What did Montcalm's Indian allies do after the withdrawal?",
#  'question: What has been found to have a higher rate of health and social problems?',
#  'question: What was the name of the former stronghold of the Huguenots in France?',
#  'question: What did the Gulf War do?',
#  'question: What did the free oxygen produced by organisms form?',
#  'question: What does MTM include?',
#  'question: What was the combined wealth of the 10 million dollar millionaires in 2008?',
#  'question: What is the definition of general disobedience?',
#  'question: What is the force related to?',
#  'question: Does the IPCC monitor climate related data?',
#  'question: What is the name of the community service fraternity at the University of Chicago?',
#  'question: What is the lithosphere?',
#  'question: What are the outcomes of market-based inequality viewed as?',
#  'question: Who defined Turing machines?',
#  'question: What did glaciers begin to do in spring?',
#  'question: Who recorded the song "Walking Into Fresno"?',
#  'question: What concept did philosophers use in the study of stationary and moving objects?',
#  'question: What does X.25 do at the network layer of the OSI Model?',
#  'question: What is the interval for a possible prime?',
#  'question: What is the role of a clinical pharmacist?',
#  'question: When did student applications decline?',
#  'question: What is the top layer of the Earth?',
#  'question: Who found the Xingu tribe settlements?',
#  'question: What do highly concentrated sources of oxygen promote?',
#  "question: What sector of the economy is Kuznets' cycle moving from?",
#  'question: What did the Better Jacksonville Plan do?',
#  'question: What country was concerned about the rise in oil prices?',
#  'question: What is the principle of non-discrimination?',
#  'question: What does Brownlee believe can be justified in opposition to non-governmental agencies?',
#  'question: What was the price of oil by the end of the 1973 oil embargo?',
#  'question: What two battles did the French Navy fail in 1759?',
#  'question: What is the principle of EU law?',
#  "question: What is the undergraduate college's liberal arts curriculum known as?",
#  'question: What is the set of problems that are hard for NP?',
#  'question: What does Janet Gray think the name huguenote would be roughly equivalent to?',
#  'question: What was the largest empire in the world?',
#  'question: How many seats does Victoria have in the Australian Senate?',
#  'question: What is the middle layer of jelly-like material called in cnidarians and ctenophores?',
#  'question: What two theories were fought in the 19th century?',
#  'question: What is the most likely result of the graph isomorphism problem?',
#  'question: What type of rock crystallizes when it melts?',
#  "question: What is the term for Kuznets' cycle?",
#  'question: What type of molecules do helper T cells and regulatory T cells only recognize?',
#  'question: Where do Trio Tribe live?',
#  'question: What did Stalin establish for the Soviet Union?',
#  'question: Who set up Ralph as earl of Hereford?',
#  "question: What was the European Union's only concern?",
#  "question: When did Kublai's government face financial difficulties?",
#  'question: When were the non-Marxist writers at their most prolific?',
#  'question: What was the purpose of the Michigan Educational Research Information Triad?',
#  'question: What is the name of the new generation of power?',
#  'question: What is the most difficult problem in NP?',
#  'question: What is the name of the public-key cryptography algorithm?',
#  'question: What was the first step in reforming the constitutional law of the European Union?',
#  'question: What was the theory modified to reflect new discoveries regarding?',
#  "question: What are the EU's primary constitutional sources?",
#  'question: How much money is awarded for solving the P versus NP problem?',
#  'question: Who are the earliest surviving records of the explicit study of prime numbers?',
#  'question: What is the fluid of choice?',
#  'question: When will Sky Q Silver set top boxes be available?',
#  'question: How many climate scientists wrote in Nature in 2010?',
#  "question: What are cydippids' little tentacles?",
#  'question: What is the main idea of the report?',
#  'question: Who instructs members which way to vote?',
#  'question: What is Sky UK Limited?',
#  'question: When did income inequality fall in the US during the High school movement?',
#  'question: Who were the two main groups of people who married Shi Tianze?',
#  'question: What is the most likely explanation for the pharmacological effect?',
#  'question: What did the Muslim Brotherhood antipathy for?',
#  'question: What are problems that can be solved in theory but take too long for their solutions to be useful?',
#  'question: Where was the Norman culture located?',
#  'question: What research group did the scientists at argue that the drought response is pushing the rainforest towards a "tipping point"?',
#  'question: How is a problem regarded as inherently difficult?',
#  'question: What can contribute oxygen to a fire?',
#  'question: What river divides Warsaw into two parts?',
#  'question: What does Neoclassical economics view inequalities in the distribution of income as arising from?',
#  'question: Time and space are the most well-known what?',
#  'question: What was the main reason Chinese physicians opposed Western medicine?',
#  'question: What became common during the Jin dynasty?',
#  'question: What is the immune system classified into?',
#  'question: What are some computational problems easier to analyze in terms of?',
#  'question: What was the name of the Mongol appointed Governor of Samarqand?',
#  'question: How far from Harvard Yard is the Quad?',
#  "question: What is Jacksonville's tenth largest population?",
#  'question: What is the name of the main rift system in southwest Germany?',
#  'question: What did Iqbal call for to be shed?',
#  'question: What is the discrete intrinsic momentum-like variable called?',
#  'question: What was the purpose of the protection of private schools?',
#  'question: What do microorganisms and toxins encounter?',
#  'question: What has helped Warsaw improve over the past decade?',
#  'question: What did Haas say in an email to the city councilors?',
#  'question: What do civil disobedients seek in the United States?',
#  'question: What is the most common prime number used for RSA?',
#  'question: What did the British order to the Acadians?',
#  'question: Where does the Rhine-Meuse Delta begin?',
#  'question: What does Bolinopsis generally feed on?',
#  'question: When did the history of the steam engine begin?',
#  'question: What happened in 1964?',
#  'question: Where is the dam that prevents the river from flowing into the Seeztal valley?',
#  'question: What is the Esteve Pharmacy now?',
#  'question: What range is Southern California known for its peaks?',
#  'question: How much more did Iran say he should pay for oil?',
#  'question: What is the goal of the capabilities approach?',
#  'question: What is stratigraphy?',
#  'question: What did the increase in skilled workers lead to?',
#  'question: Who conquered England in 1066?',
#  "question: What was Langlade's objective?",
#  'question: Who is the vice president of the United States?',
#  'question: What did the Edict of Nantes do to Protestants?',
#  'question: What is Trioxygen usually known as?',
#  'question: What is the name of the receiver that can be used to view encrypted content?',
#  'question: What did the water pump create?',
#  'question: What is stratigraphy?',
#  'question: What did South Africa fight against?',
#  'question: What type of combustion does triplet oxygen prevent?',
#  'question: What is a problem in many fields?',
#  'question: What does Rosenfield say has very low levels of inequality?',
#  'question: What is the component that accelerates an object by either slowing it down or speeding it up?',
#  'question: Who originally inhabited Jacksonville?',
#  'question: What happened to the flow of the Rhine?',
#  'question: What is the most of the lost forest used for?',
#  'question: Who wrote about the Great Pestilence?',
#  'question: What did Montcalm and the Indians disagree about?',
#  'question: What is wind-blown dust called?',
#  'question: What does X.25 do at the network layer of the OSI Model?',
#  'question: What was the highest level of persecution?',
#  'question: How close are the independent shops and bookstores in the neighborhood?',
#  'question: Why was the name Datanet 1 used?',
#  'question: How do ideal strings transmit tension forces?',
#  'question: Who was the Greek writer on mechanics?',
#  'question: What does Brownlee believe can be justified in opposition to?',
#  'question: What has helped Warsaw improve over the past decade?',
#  'question: How were the protesters arrested?',
#  'question: What did the principal Treaties that form the European Union begin with?',
#  'question: What has Richard Lindzen said about the WGI Summary for Policymakers?',
#  'question: What is the name of the particle physics laboratory that Chicago has a joint stake in?',
#  'question: Why can unemployment harm growth?',
#  'question: What is one of the problems that people would like to solve efficiently but no efficient algorithm is known?',
#  'question: When did famine begin?',
#  'question: What is the Rhine Gorge known as?',
#  'question: How many auricles do Lobates have between their lobes?',
#  'question: Local elites would be exposed to the benefits and luxuries of what culture and lifestyle?',
#  'question: What treaty protects the "freedom of establishment" in article 49?',
#  'question: How long are the cilia in a comb plate?',
#  'question: What was the name of the academy founded by Tugh Temür?',
#  'question: When was Harvard formed?',
#  'question: What did the Lisbon Treaty do to existing treaties?',
#  'question: What is the magnitude of the San Andreas Fault?',
#  'question: What bacteria lives inside a protective capsule that prevents lysis by complement?',
#  'question: Who was the second in command of Lord Loudoun?',
#  'question: What industries were steam engines used in?',
#  'question: What is the longest suspension bridge in Germany?',
#  "question: What platform was launched to expand BSkyB's analogue service?",
#  'question: What border is to the south?',
#  'question: What are pharmacy informatics trained to participate in?',
#  "question: In the 1990s, what percentage of the world's electricity production was produced by steam turbines?",
#  'question: What is the term for refineries, process chemical, power generation, mills and manufacturing plants?',
#  'question: What did Donald Davies independently develop?',
#  'question: What do geologists study?',
#  'question: What are two examples of effector cells?',
#  'question: Why are the islands of Orkney, Shetland and the Western Isles smaller?',
#  'question: What is the short for antibody generators?',
#  'question: Where are health and social problems more common?',
#  'question: What happened in the late 1980s?',
#  'question: What is the sister lineage of Ctenophores?',
#  'question: What was the Six-Day War?',
#  'question: What causes a lower level of economic growth?',
#  "question: When did the Central Pacific Railroad establish a station near Easterby's?",
#  'question: How were messages delivered?',
#  'question: What is the longest river in Germany?',
#  'question: What insect uses prime numbers?',
#  'question: How many votes are there in the European Council?',
#  'question: What type of processes can be studied?',
#  'question: What is the most common number used for RSA?',
#  'question: What did Bassett use blank space to denote?',
#  'question: Who is highly likely to be present in a building construction project?',
#  'question: What did isotopic dates allow to assign to rock units?',
#  'question: What was the Forte rebranded as?',
#  'question: What is the Rankine cycle sometimes referred to as?',
#  'question: Who has been praised by Muslims for driving Israel out of the Gaza Strip?',
#  'question: What is the acronym for Public-Private Partnering?',
#  'question: How much retail activity does the Fresno Chandler neighborhood have?',
#  'question: What is the general principle of proportionality?',
#  'question: What County is the most commuter to?',
#  'question: What does the Chinese say about the Da Yuan Tong Zhi?',
#  'question: What are found in all plants and animals?',
#  'question: What country did the Huguenots fight in the Low Countries?',
#  'question: How were granaries built to protect against famines?',
#  'question: What is the Esteve Pharmacy now?',
#  'question: What have civil disobedients chosen?',
#  'question: What river is Warsaw located on?',
#  "question: Who was Newcastle's principal military advisor?",
#  'question: Who discovered the geoglyphs in 1977?',
#  'question: What was the name of the memoir Maclure wrote?',
#  'question: What is the primary goal of a guilty plea?',
#  'question: What did Mote call the status of people within the four-class system?',
#  "question: What type of private school is St Cuthbert's College?",
#  'question: What are social welfare programs?',
#  'question: What was the name of the ITV Digital replacement channel?',
#  'question: What is structural geology?',
#  'question: What could absolute dates be applied to?',
#  'question: In what time period was the coast line roughly at the same location?',
#  'question: What was the isolated subdivision known as for years?',
#  'question: What is the name of the solid upper mantle?',
#  'question: What is the World Meteorological Organization?',
#  'question: When did the last glacial end?',
#  'question: What is the algorithm called if T(n) is a polynomial in n?',
#  'question: Who does not benefit from a project that fails to adhere to codes?',
#  'question: What did HT believe happened in 1924?',
#  'question: What continents did France focus on after 1850?',
#  'question: What organic compound contains the most amount of oxygen?',
#  'question: What is the average discharge of the Moselle?',
#  'question: What does Lindzen think the SPM does?',
#  'question: What are considered more accurately to be "fundamental interactions"?',
#  'question: What is the main use of automobiles in Southern California?',
#  'question: In what year did the average American vehicle move 17.4 miles per gallon?',
#  "question: What percentage of Warsaw's Jewish population was displaced into the Warsaw Ghetto?",
#  'question: How much coal did Watt burn?',
#  "question: What is Melbourne's ranking in Australia?",
#  'question: What law of motion states that objects continue to move in a state of constant velocity unless acted upon by an external net force or resultant force?',
#  'question: When did the plague recur in Europe?',
#  'question: What type of exponentiation is used in the Diffie-Hellman key exchange?',
#  'question: What is an increase in the income share of the bottom 20 percent associated with?',
#  'question: Where is Guernsey located?',
#  'question: Where is Bielany Forest located?',
#  'question: Where is the lowest point of Warsaw located?',
#  'question: What percentage of Victorians describe themselves as Christian?',
#  'question: What was the German encyclopedia Knaurs Lexikon presumably trying to correct?',
#  'question: Which professional skateboarder lives in southern California?',
#  'question: What is the unbalanced centripetal force felt by any object always?',
#  'question: When did Republicans become supportive of the French empire?',
#  'question: What did Avogadro arrive at by 1811?',
#  'question: Who applies European Union law?',
#  'question: What temperate climate produced hard-working, moral, and upstanding human beings?',
#  'question: What is the name given to several higher energy species of molecular O 2?',
#  'question: What platform has been proposed to measure the radiance coming from vegetation canopies?',
#  'question: What is the income gap in Bahrain?',
#  'question: What was AUSTPAC?',
#  'question: Who established the IPCC Trust Fund?',
#  'question: Capitalist firms substitute capital equipment for what?',
#  'question: What is the financial interest of a physician in diagnosing conditions?',
#  'question: How much dust is windblown out of the Sahara each year?',
#  'question: What is the annual budget of Student Government?',
#  'question: What happens when the water level drops?',
#  'question: Why is O2 used by complex forms of life?',
#  'question: What type of civil disobedience does LeGrande encourage?',
#  'question: When did the Jin dynasty begin?',
#  'question: How much did Francovich claim from the Italian government for his loss?',
#  'question: What was built to protect the Ohio Country from illegal settlement?',
#  'question: How do Platyctenids use the pharynx?',
#  "question: What is the main focus of Southern California's economy?",
#  'question: How much carbon dioxide does the Amazon absorb in a typical year?',
#  'question: What was expressed by Joseph Chamberlain and Lord Rosebury?',
#  'question: What was the name of the interactive service BSkyB launched under?',
#  'question: Who did Ralph fight with?',
#  'question: How far from the Baltic Sea is Warsaw?',
#  "question: What theory is used to describe the world's developed and developing nations?",
#  'question: Who provides the bill of quantities?',
#  'question: How many attempts did the British have to defeat the French?',
#  'question: What is ozone?',
#  'question: What is the main international treaty on climate change?',
#  'question: What country was the name Black Death first used in?',
#  'question: When was the Duchy reincorporated into the Polish Crown?',
#  'question: Who is open to debates and committee meetings?',
#  'question: What was the result of the Merit Network, Inc.?',
#  'question: What is opposed by static friction?',
#  'question: Why do geochronologists precisely date rocks within the stratigraphic section?',
#  'question: What does the Presiding Officer decide about who speaks in chamber debates?',
#  'question: When was the European Council set up?',
#  'question: What is the name of the Polish university?',
#  'question: What did the PLoS Pathogens team investigate?',
#  'question: What type of rainforest is the Amazon?',
#  'question: What drew visitors to other areas?',
#  'question: What can be defined by bounding the time or space used by the algorithm?',
#  'question: When was Anwar Sadat assassinated?',
#  'question: What was the name of the area that stretched across middle Europe?',
#  'question: What would happen if the head of government refused to enforce a decision of the highest court?',
#  'question: What enzyme is found in saliva, tears, and breast milk?',
#  "question: What does the EU's legitimacy rest on?",
#  'question: What is another term for the oil crisis?',
#  'question: When were the three putative species found in the Burgess Shale?',
#  'question: What type of microscope is used to analyze rock samples?',
#  'question: Where is the highest point on the right side of Warsaw?',
#  'question: Who rented the buildings for the Parliament?',
#  'question: Who negotiated a capitulation with Amherst?',
#  'question: Who must be punished?',
#  'question: What does colonialism refer to?',
#  'question: What does the ozone layer of the upper atmosphere function as?',
#  'question: What did Lenin believe imperialism was a natural extension of capitalism?',
#  'question: What is the more common name for the war between France and Great Britain?',
#  'question: What did Jules Ferry say the higher races have a duty to do?',
#  'question: Why is Joseph Priestley given priority?',
#  'question: What is enzootic?',
#  'question: What features does Harvard claim will benefit the community?',
#  'question: What had dropped so far that natural sedimentation by the Rhine and coastal processes could compensate the transgression by the sea?',
#  'question: How much did the Great Internet Mersenne Prime Search project win in 2009?',
#  'question: What is the physics now described by instead of Newtonian equations?',
#  'question: Who pays for pharmacists in Australia?',
#  'question: What are sticky and adhere to prey?',
#  'question: What is the name of the NBC affiliate of KMJ?',
#  'question: What did the Convention publish in 1995?',
#  'question: What direction does the unit vector point in?',
#  'question: What time is set aside for question periods in the debating chamber?',
#  'question: What does the Presiding Officer submit a bill to the Monarch for?',
#  'question: What provided the basis for the structure of the Parliament?',
#  'question: What is the difference between women and men?',
#  'question: What are the combs also known as?',
#  'question: Where did oil companies look for ways to increase oil supplies?',
#  'question: When did BSkyB and Microsoft announce their settlement?',
#  'question: What tribe is the region of the Amazon rainforest?',
#  "question: What caused Victoria's highest temperature since World War II?",
#  'question: What type of Saudi-based interpretation of Islam was promoted by the Saudi funding?',
#  'question: What happens when the water level drops?',
#  'question: Who has design authority over all digital satellite receivers capable of receiving their service?',
#  'question: What are lenses called?',
#  'question: What is the notion of hard problems?',
#  'question: What are secondary schools called?',
#  'question: How much dust is windblown out of the Sahara each year?',
#  'question: What is the computational problem of determining whether two finite graphs are isomorphic?',
#  'question: Who was the Egyptian President?',
#  'question: What is the sister lineage of Ctenophores?',
#  'question: Where is the majority of the Amazon rainforest located?',
#  'question: What type of rock is formed when a rock crystallizes from melt?',
#  'question: In what year were two IPCC Special Reports finalized?',
#  'question: How many steps can it take to build on government land?',
#  'question: What battle did Union forces fight a Confederate army at?',
#  'question: What political parties did Iqbal criticize?',
#  'question: What did Tugh Temür support?',
#  'question: What is the cost of a delay in a construction project?',
#  'question: When did coal miners and railroad workers strike?',
#  'question: What is the most useful instrument for analyzing the performance of steam engines?',
#  'question: What do most Ersatzschulen have?',
#  'question: How is much unregistered property held in informal form?',
#  'question: What type of hermaphrodites are the eggs and sperm mature at different times?',
#  'question: What enables small populations to grow at an explosive rate?',
#  'question: Local elites would be exposed to the benefits and luxuries of what culture and lifestyle?',
#  'question: What is the highest court able to interpret European Union law?',
#  'question: What is the triplet element?',
#  'question: When do underbids occur?',
#  'question: What is a common problem in algebraic number theory?',
#  'question: How did scientists realize that air could be liquefied?',
#  'question: What do some proofs of complexity-theoretic theorems assume some concrete choice of?',
#  'question: What tribes did Genghis Khan unite?',
#  "question: When was Thoreau's essay published?",
#  'question: Who is usually awarded a contract?',
#  'question: What was Joseph Haas arrested for?',
#  'question: What is the principle of non-discrimination?',
#  'question: When did Zhu Shijie die?',
#  'question: What is the executive summary of the WG I Summary for Policymakers report certain emissions are doing?',
#  "question: What did the UK government's benefits agency check in 2012?",
#  'question: What did environmental determinism suggest tropical environments created?',
#  'question: What system protects the brain?',
#  'question: What did the Court of Justice hold was unjust?',
#  'question: What did Céloron say about the Natives of the localities?',
#  'question: How much did ITV increase its offer to keep control of the rights?',
#  'question: What is as important as an identification of symptoms?',
#  'question: When did BSkyB discontinue the Sky+ Box?',
#  'question: How is the intuitive understanding of forces quantified?',
#  'question: What are environmentalists concerned about?',
#  'question: How did Gou calculate his astronomical calculations?',
#  'question: Why are mass marriage ceremonies facilitated?',
#  'question: How many British soldiers were killed or injured?',
#  "question: What movements were inspired by Qutb's writings?",
#  'question: What occupation did many Huguenots do?',
#  'question: What did a driver do to allow steam pressure to be increased?',
#  'question: What are companies focusing on in the design-build process?',
#  'question: What system protects the brain?',
#  'question: What was the current warming period compared to?',
#  'question: Oxygen is what?',
#  'question: Why did the Maroons withdraw from the UAA?',
#  'question: How far south did the rainforest extend from 66-34 Mya?',
#  'question: What material gained weight in rusting?',
#  'question: What did Saint-Pierre say about the Summons?',
#  'question: What do complexity classes depend on?',
#  'question: What was the mean annual deforestation rate from 2000 to 2005?',
#  'question: When was the Confederation of the Rhine established?',
#  "question: What law is Newton's?",
#  'question: What do some species do to adapt to water of different densities?',
#  'question: Why is the French and Indian War still the standard name in the US?',
#  'question: Who is a comedian?',
#  'question: What class contains the complement problems?',
#  'question: Who was deep into Polish territory and pursuing the Germans toward Warsaw?',
#  'question: What are the names of the two organizations that established the IPCC?',
#  'question: How long is the section of the Rhine?',
#  "question: What is Edward Durrell Stone's school?",
#  'question: What is the angle of the pistons in a double expansion group?',
#  'question: When was the European Convention on Human Rights established?',
#  'question: What was the name of the bank that was spun off in 1976?',
#  'question: When was the first census undertaken?',
#  'question: What is the mass that accelerates at 1 m ⁇ s ⁇ 2 when subjected to a force of 1 kgf?',
#  'question: What is the second busiest container port in the US?',
#  'question: What would happen if the population were fewer?',
#  'question: Who provides the bill of quantities?',
#  'question: How did the Plowshares organization temporarily close GCSB Waihopai?',
#  'question: What was the first aviation community to be built?',
#  'question: Where were official photographs and interviews held?',
#  'question: Where was Abercynon located?',
#  'question: What type of representation system was used in the Victorian Legislative Council elections?',
#  'question: What is the emerging field of bioinformatics-based studies of immunogenicity called?',
#  'question: What is the Islamic Salvation Front?',
#  'question: Who gave a speech during the divestment?',
#  'question: When did the Meuse and Waal merge to form Merwede?',
#  'question: What is the term for a mechanism that moves fuel from a supply bin to a firebox?',
#  'question: How many stages do bills pass through Parliament?',
#  'question: How many tons of dust are windblown out of the Sahara each year?',
#  'question: What is the sum of the integer m that is greater than 1?',
#  'question: What is the special category of 1?',
#  'question: What has the Brotherhood become in the Islamic world?',
#  'question: What did sceptics of the bubonic plague theory argue about the population?',
#  "question: What was William Johnson's job?",
#  'question: What two states did the Iroquois Confederation dominate?',
#  'question: What does the HT take about Muslim history?',
#  'question: What is a strengthening of twin prime conjecture?',
#  "question: What was the main problem with Shirley's efforts to fortify Oswego?",
#  'question: What is a name given to several higher energy species of molecular O 2?',
#  "question: What can't be included in an IPCC report?",
#  "question: In what year did the English High Court of Justice find that SkyDrive infringed on Sky's trademark?",
#  'question: What are composite numbers called?',
#  'question: Why were the Huguenots killed?',
#  "question: When was Thoreau's essay published?",
#  'question: What did the pharmas use?',
#  'question: What does Steven Barkan say a defendant must do if they want to win an acquittal?',
#  'question: What battle did the Tran dynasty defeat the Mongols?',
#  'question: Where is the phrase "Dà Yuán" from?',
#  'question: What are three different ways of measuring the time complexity of different inputs of the same size?',
#  'question: What is the most familiar effect of the weak force?',
#  'question: How long can algorithms solve the NP-complete knapsack problem?',
#  'question: Who provides rail transport in Victoria?',
#  'question: What did the Meuse form with Waal and Lek?',
#  "question: What was Maududi's most influential activity?",
#  'question: What is the location in which the entire sedimentary sequence of the Grand Canyon can be seen over a length of less than a meter?',
#  'question: What is the emergency supply of O 2 supplied to passengers in pressurized commercial airplanes?',
#  'question: What did the British offer France to surrender?',
#  'question: Why was oil sold at a higher price?',
#  'question: What did Bassett focus his analysis of?',
#  'question: What type of climate does Jacksonville have?',
#  'question: What is the number of seats the party won in the region?',
#  'question: What did Lenin believe capitalist economies needed to do to increase their capital?',
#  'question: What caused the situation in New France to be worse?',
#  'question: What genus lacks tentacles and tentacle sheaths?',
#  'question: Who did Prince Louis de Condé arrange with to establish a Huguenot community in Saarland?',
#  'question: What other societies had great influence on the Royal Geographical Society of London?',
#  "question: What is used in medicine to increase oxygen levels in the patient's blood?",
#  "question: What is Melbourne's rank among Australia's most populous states?",
#  'question: Who deployed its 40th Army into Afghanistan in 1979?',
#  'question: What is the coldest part of Victoria?',
#  'question: Who engineered and operated the vBNS?',
#  'question: What covered Scandinavia, the Baltics, Scotland and the Alps during the Last Glacial Maximum?',
#  'question: How many general education categories are undergraduate students required to complete?',
#  'question: Who ruled all of China?',
#  'question: When did Western forces invade Iraq?',
#  'question: Where does the last active Huguenot congregation worship?',
#  'question: Who designed the Scottish Parliament building?',
#  "question: What does Warsaw's mix of architectural styles reflect?",
#  'question: What did Vaudreuil attack?',
#  'question: Who has the initiative to propose legislation?',
#  'question: What was the right of Steymann to do?',
#  "question: When did Germany's participation in Western imperialism become negligible?",
#  'question: What type of architecture is the Royal Castle?',
#  "question: What did the court of Appeals for the First Circuit believe about the defendant's defiant speech?",
#  'question: Where does the river turn to near Chur?',
#  'question: Who said the term "civil disobedience" has been used to describe everything from bringing a test case in the federal courts to taking aim at a federal official?',
#  'question: What is the average global surface temperature projected to increase by by?',
#  'question: Why is it believed that cicadas are able to specialize as predators on Magicicadas?',
#  'question: At what temperature does oxygen condense?',
#  'question: What is the name huguenote compared to?',
#  "question: What was the name of Philo's work?",
#  'question: Whose acts have been described as revolutionary civil disobedience?',
#  'question: What did Orientalism do to the West?',
#  'question: What are stators?',
#  'question: What is oxygen stored in smaller cylinders?',
#  'question: What is the point at which different radiometric isotopes stop diffusing into and out of the crystal lattice?',
#  'question: What county is New Rochelle located in?',
#  "question: What is the Court of Justice's opinion on the issue of indirect discriminatory measures?",
#  "question: What movement did Iqbal's address in 1930 inspire?",
#  'question: Who invented the Woolf high-pressure compound engine?',
#  'question: What made it difficult for low income residents to keep pace?',
#  'question: What was the name of the public switched data network?',
#  'question: What century saw the beginning of the Age of Imperialism?',
#  'question: What are the three subsectors of the Standard Industrial Classification?',
#  'question: Who argues that civil disobedience can be justified if it reflects a larger challenge to the legal system?',
#  'question: What is the output corresponding to the given input?',
#  'question: What did the Treaties seek to do?',
#  'question: What is evidence accumulating since the 1980s indicating?',
#  'question: What type of number generators are prime numbers used for?',
#  'question: What did AUSTPAC support?',
#  'question: What percentage of tertiary enrollment is from the private sector?',
#  'question: What does the minister who is the minister of the debate and motion do?',
#  'question: What type of immune system is activated by the innate response?',
#  'question: What did protesters complain about in the allocution speeches?',
#  'question: Prime ideals are an important tool and object of study in commutative algebra, algebraic number theory and what kind of geometry?',
#  'question: What percentage of the population is black?',
#  'question: When was the Battle of Warsaw fought?',
#  'question: Why did Hutchins eliminate varsity football from the university?',
#  'question: What force is proportional to volume for objects of constant density?',
#  "question: Where is Polonia's home venue?",
#  'question: What are cells called?',
#  'question: What was the most widely accepted estimate for the Middle East during this time?',
#  'question: What part of the Earth is below the crust and lithosphere?',
#  'question: When were private church schools established in South Africa?',
#  'question: What acts on a load?',
#  'question: What gas is released from the other zeolite bed?',
#  'question: What is needed to trigger combustion?',
#  'question: What did the maidens float their wreaths on the water to predict?',
#  'question: Who suggested that the name huguenote would be roughly equivalent to little Hugos?',
#  'question: What are the largest construction projects referred to as?',
#  'question: What is the process of building a building or infrastructure?',
#  'question: Who owns V/Line?',
#  'question: What is the best known algorithm for integer factorization?',
#  'question: What principle is the Mask of Anarchy a statement of?',
#  'question: What was the atmospheric engine an improvement over?',
#  'question: What do the strips of adhesive epithelial cells do when the animal is not feeding?',
#  'question: What type of museum is the National Museum?',
#  'question: What type of administrative structure did Kublai leave unchanged?',
#  'question: At what time do members vote on whether they agree to the general principles of the final bill?',
#  "question: What form is Polignac's conjecture?",
#  'question: What are two examples of ignition events that can trigger combustion?',
#  'question: What is septicemic?',
#  'question: What is the central role of in number theory?',
#  'question: What does Bedau believe the harmlessness of civil disobedience may serve?',
#  'question: What is the phylum of cnidarians called?',
#  'question: What type of sports are popular in southern California?',
#  'question: Where is Sunnyside located?',
#  'question: What happens to businesses that offer below market wages?',
#  "question: What is the Nederrijn's name?",
#  'question: When was the Rhine fully within the Holy Roman Empire?',
#  'question: What did Saint-Pierre say about the French claim to the Ohio Country?',
#  'question: When was the Tower Theatre built?',
#  'question: How tall is the Bank of America Tower?',
#  'question: What are the names of the two organizations that created the IPCC?',
#  'question: When did the plague finally reach England?',
#  'question: What is one reason why women are more likely to consider factors other than pay when looking for work?',
#  'question: What did the Battle of Jumonville Glen do?',
#  'question: What is the Kearney Boulevard between?',
#  'question: Why did Warsaw become the capital of the Commonwealth?',
#  "question: What was Langlade's objective?",
#  'question: Why has the push to legalize importation of medications from Canada and other countries been successful?',
#  'question: What is a reduction a transformation of one problem into?',
#  'question: What is the mayor of Warsaw called?',
#  "question: What was the average duty of Watt's low pressure engines?",
#  'question: What did the people of tropical climates need from the European empire?',
#  'question: What does education create for those with high demand for workers?',
#  'question: What type of architecture is Czapski Palace?',
#  'question: Who adopted the Social Charter in 1989?',
#  'question: What percentage of oxygen is present at standard pressure?',
#  'question: What country imported the Toyota Corona?',
#  'question: How many insect species are in the Amazon?',
#  'question: Who did  ⁇ gedei offer Kublai a position in Xingzhou, Hebei?',
#  'question: What role would the head of government have in order to act?',
#  'question: What was the population density per square mile?',
#  "question: How many times higher was the duty of Watt's low pressure engines?",
#  'question: What assistance does the Muslim Brotherhood provide to students from out of town?',
#  'question: What three offices did the central government have?',
#  'question: Where does free oxygen occur?',
#  'question: What are prime numbers of the form 2p  ⁇  1 called?',
#  'question: What do petrologists do in the field?',
#  'question: What continent is the Rhine?',
#  'question: Where is the unbalanced centripetal force felt by an object always directed?',
#  'question: When was earthenware movable type invented?',
#  'question: How do juveniles behave in the flat, bottom-dwelling platyctenids?',
#  'question: What basin did the water flow across to the Pacific?',
#  'question: When did the Duchy of Normandy begin?',
#  'question: What is Pedanius Dioscorides famous for?',
#  'question: What caused the decline of tourism in Jacksonville?',
#  'question: What percentage of O2 is typically in gas supplied through oxygen masks?',
#  'question: Where do ctenophores occur in high numbers?',
#  'question: What are the Westminster MPs unable to vote on?',
#  'question: What campaign did the Scottish National Party run?',
#  'question: What dynasty did the Yuan dynasty precede?',
#  'question: How many species of plants of economic and social interest have been registered in the Amazon rainforest?',
#  'question: What is the name of the forest in the Vistula plateau?',
#  'question: What was the name of the railway that used the Salamanca?',
#  'question: What is the name of the oldest street in the United States?',
#  'question: How large are adult ctenophora?',
#  'question: What is the name of the Australian political party?',
#  'question: Who was awarded a Nobel Prize in 1905 for proofs of microorganisms?',
#  'question: How much did sea level drop in the Ice Ages?',
#  'question: Why is the evolutionary strategy used by cicadas of the genus Magicicada?',
#  'question: What percentage of the Scottish electorate voted for an elected assembly?',
#  'question: What weapon was becoming an effective battlefield weapon by the 1880s?',
#  'question: What happens to the ordinary election?',
#  "question: What was the historical measure of a steam engine's energy efficiency called?",
#  'question: What are Members Business motions?',
#  'question: What canal was diverted to the lake?',
#  'question: What is used to recirculate water and recover the latent heat of vaporisation?',
#  'question: Who misinterpreted the motion as being caused by the applied force?',
#  "question: When was Raymond Smullyan's study of rudimentary sets published?",
#  'question: How many students were enrolled in the fall quarter of 2014?',
#  'question: What does X.25 do at the network layer of the OSI Model?',
#  'question: How many earthquakes occur in Southern California each year?',
#  'question: What is the maximum partial pressure of oxygen gas?',
#  'question: What is in large part the result of stages of development?',
#  'question: What type of forces are other than friction?',
#  'question: Who mapped the Alta Vista Tract?',
#  'question: What did the Chinese surname barracks mean?',
#  'question: When did BSkyB announce its intention to replace its three free-to-air digital terrestrial channels with four subscription channels?',
#  'question: Where does the European Court of Justice draw inspiration from?',
#  'question: What was the main difference between herbal remedies and mongol shamanism?',
#  'question: How many U.S. presidents are alumni of Harvard?',
#  'question: What percentage of the population was Jewish?',
#  'question: What is the internal cavity?',
#  'question: Toghtogha finished the official histories of which dynasties?',
#  'question: What are the dunes of the highest terraces of the plain moraine plateau?',
#  'question: What was Tymnet?',
#  'question: What percentage of carbon does Amazonian forests account for in ecosystems?',
#  'question: What did the British offer France to surrender?',
#  "question: How much more than normal sea-level O 2 partial pressure in astronaut's arterial blood?",
#  'question: What document was the first Protestant confession of faith in the Americas?',
#  'question: How did Hobson believe domestic social reforms could cure imperialism?',
#  'question: Where did the French withdraw from Fort William Henry?',
#  'question: What output is expected for every input?',
#  'question: What country is Lake Constance located in?',
#  'question: What is civil disobedience defined as pertaining to?',
#  'question: What is the upper house of the Parliament of Victoria?',
#  'question: What was the Brotherhood described as for many years?',
#  'question: What is a Pharmacy Technician in the UK considered?',
#  'question: Why was Polonia relegated from the top flight in 2013?',
#  'question: What is issued after the final inspection?',
#  'question: What is an important factor in the creation of inequality?',
#  'question: How many times did Polonia win the cup?',
#  "question: Kuznets' curve predicts that income inequality will what?",
#  'question: What promoted trade between East and West?',
#  'question: On what day do plenary meetings usually take place?',
#  'question: Did British colonies have standing forces?',
#  'question: What was the initial design of DECnet?',
#  'question: What was the civil war against Ragibagh known as?',
#  'question: When was the Single European Act signed?',
#  'question: What is supplementation used to treat?',
#  'question: Who did the Duke Yansheng Kong Duanyou flee with?',
#  'question: What did the term "Germany" refer to?',
#  'question: What subgroup of Timucua people lived in Jacksonville in the 16th century?',
#  'question: When did the US and the USSR agree on a negotiated settlement?',
#  'question: What is the Latin name for Rhine?',
#  'question: SAT solvers routinely handle large instances of what problem?',
#  'question: Where did the Huguenots move to?',
#  'question: What type of business districts are in Downtown Burbank?',
#  'question: What is the largest city in New Zealand?',
#  'question: Who is Stage 1 presented to?',
#  'question: How many square kilometers does the Amazon basin cover?',
#  'question: What percentage of Victorian agricultural production increased in 2003-2004?',
#  'question: Who discovered the Compton Effect?',
#  'question: What is the trade magazine for the construction industry?',
#  'question: Why did the British want to keep the islands?',
#  'question: What month is the warmest in Fresno?',
#  'question: What do stratigraphers use to get a better view of the subsurface?',
#  'question: When did the Holy Roman Empire form?',
#  'question: What is the dominant system of host defense in most organisms?',
#  'question: What is the procedural consequence of the establishment of the Scottish Parliament?',
#  'question: Where are the stators fixed?',
#  'question: What does increasing inequality harm?',
#  'question: Where do petrologists identify rock samples?',
#  'question: What were some of the medical techniques that were transmitted westward to the Middle East?',
#  'question: What did protesters complain about in their allocution speeches?',
#  'question: What article of the Treaty on European Union states that Commissioners should be "completely independent"?',
#  'question: What increases rapidly as per capita income increases?',
#  'question: What is the average salary for a professional in the construction industry in the Middle East?',
#  'question: How many additional putative species were found in the Burgess Shale?',
#  'question: Where did the French trade in fur?',
#  'question: Who discovered some of the oldest pottery in the US?',
#  'question: Who were the later Yuan emperors separated from?',
#  'question: What does the approach believe people can work towards?',
#  'question: Why do some civil disobedients feel it is incumbent upon them to accept punishment?',
#  'question: Where did the disease spread from Italy?',
#  'question: When are some species of ctenophores disturbed?',
#  'question: What caused the underlying economic pressure on oil prices?',
#  'question: What is the quantitative answer to the traveling salesman problem?',
#  'question: Newtonian mechanics were developed to describe how forces affect idealized point particles rather than what?',
#  'question: Between what years was the Black Death present in at least one location in the Islamic world?',
#  'question: Why did the British operations fail in the frontier areas of Pennsylvania and New York?',
#  'question: What is the best known algorithm for integer factorization?',
#  'question: What molecules are tumor antigens presented on?',
#  'question: Where do petrologists identify rock samples?',
#  'question: What did the study suggest on February 1, 2007?',
#  'question: What revolution allowed factories to locate where water was unavailable?',
#  'question: What type of region is San Diego-Tijuana?',
#  "question: What is the effect of a ctenophores' luminescence on their body size?",
#  'question: What is an immediate or anaphylactic reaction?',
#  'question: What profession are pharmacists?',
#  'question: How many students attend private schools in New Zealand?',
#  'question: Who dominated the military planning?',
#  'question: When was the second edition of the Black Death published?',
# ...
#  'question: Who was one of the earliest Persian geologists?',
#  'question: What river flows through the Hollands Diep and Haringvliet estuaries?',
#  'question: Who did many Han Chinese and Khitan defect to fight against?',
#  'question: What do lead authors of IPCC reports assess?',
#  'question: What is the principle of succession?',
#  'question: When did Tropical Storm Fay hit Jacksonville?',
#  'question: What is thought to be partially responsible for weakened immune responses in aging individuals?',
#  'question: What do many farms in the Western Cape province still bear?',
#  'question: What is geared to students enrolled in priority courses?',
#  'question: How old are pupils in the UK who are prepared to enter public schools?',
#  'question: What was Telenet?',
#  'question: How many men attended Harvard College for every woman studying at Radcliffe?',
#  'question: What does a country acquire as it develops?',
#  'question: Where did Marin build a second fort?',
#  "question: What are Gandhi's acts described as?",
#  'question: How has the debate about the extent of the reduction in the rainforest been resolved?',
#  "question: How many regulars did Abercrombie's force have?",
#  'question: What is the most favorable comparison between the Muslim Brotherhood and?',
#  'question: Who was the Byzantine general who stopped Roussel de Bailleul?',
#  'question: Why did Millerton residents move to Fresno?',
#  'question: Why is Priestley given priority in the discovery of dephlogisticated air?',
#  'question: Where did the first variant of the plague enter Europe?',
#  'question: What two films did Audra McDonald perform at the Tower Theatre?',
#  'question: What was the name of the Yuan legal system?',
#  'question: When was Sky Digital launched?',
#  'question: What country supported communist movements after World War II?',
#  'question: Who founded the Muslim Brotherhood?',
#  'question: What is oxygen supposed to be?',
#  'question: What pathway is conserved across all eukaryotes?',
#  'question: What account for forces that cause all strains?',
#  'question: What does the ASER do?',
#  'question: When was the heyday of secular Arab nationalism?',
#  'question: What type of literature does LeGrande find on civil disobedience?',
#  'question: What are some of the other important complexity classes?',
#  'question: What pump is used to supply water to the boiler during operation?',
#  "question: How has Southern California's economy been affected by the housing crash?",
#  'question: Who pleaded guilty to the Camden 28 case?',
#  'question: What is the centre-left political party of Australia?',
#  'question: When did Tugh Temür die?',
#  'question: What is a simple example of a probabilistic test?',
#  'question: What co-receptor recognizes the MHC:antigen complex?',
#  'question: What was the purpose of the lower canal at Fußach?',
#  "question: What is the maximum number that Goldbach's conjecture has been verified for?",
#  'question: Education helps to unleash the productive potential of who?',
#  'question: What was the name of the 1978 Supreme Court case?',
#  'question: What type of design was typical of Eastern bloc countries?',
#  'question: What does the word ctenophora mean?',
#  'question: What was the name of the town of the Ubii?',
#  'question: What type of steam engine does not require valves to direct steam into and out of the cylinder?',
#  'question: What are the composite numbers called?',
#  'question: Who was the Chairman of the Subcommittee on Oversight and Investigations?',
#  'question: What did the NSFNET promote in the US?',
#  "question: What is the world's busiest general aviation airport?",
#  'question: In what year were all parts of the Mongol Empire selling their children into slavery?',
#  'question: What are the two forms of environmental determinism?',
#  'question: What is irreducible if an element is not a unit?',
#  'question: What force is unified by the connection between electricity and magnetism?',
#  'question: What do activists do when they commit civil disobedience?',
#  'question: What is the condition for the fraction 1/p to be prime?',
#  'question: What did the price controls do to the oil industry?',
#  'question: What was the name of the construction that Harvard halted?',
#  'question: What do hospital pharmacies usually do?',
#  'question: What are auricles?',
#  'question: What is the main international treaty on climate change?',
#  'question: What was the name of the garden that was formally a royal garden?',
#  'question: What did Graham Twigg produce in 1984?',
#  'question: How many bodies of water does Lake Constance consist of?',
#  'question: Where does the cannonball fall when it is actually conducted?',
#  'question: What regulatory factor does macrophages produce?',
#  'question: Who can interpret the Treaties?',
#  'question: What country was involved in a civil war?',
#  'question: How did the industrialized nations react to the currency fluctuations?',
#  'question: Where did the British resettle Acadians?',
#  'question: What pressure does the Rankine cycle operate at?',
#  'question: What is the answer to a decision problem?',
#  'question: If graph isomorphism is NP-complete, the polynomial time hierarchy collapses to what level?',
#  'question: What was free movement based on?',
#  'question: What did Nixon do on October 19?',
#  'question: What article of the Free Movement of Workers Regulation states that workers can take up employment, conclude contracts, and not suffer discrimination?',
#  'question: When were geoglyphs discovered on deforested land?',
#  'question: What was the most important feature of the Mazda 616?',
#  'question: What is the largest and southern main branch of the Rhine?',
#  'question: What is the inner surface of the cavity lined with?',
#  'question: What company runs major record companies?',
#  'question: What is the term for partially filled orbitals?',
#  'question: What two forces can be written as a sum of?',
#  'question: Who analyzes samples of stratigraphic sections that can be returned from the field?',
#  'question: What was the name of the multi-volume masterpiece that Pierre Bayle wrote and published?',
#  'question: What was the name of the calendar that Gou used?',
#  'question: What do ctenophores have no?',
#  'question: What two Protestant European nations did the Huguenot émigrés move to?',
#  'question: How much is oxygen gas obtained by non-cryogenic technologies?',
#  'question: Where is much of the work of the Scottish Parliament done?',
#  'question: Where are the rotors mounted on a steam turbine?',
#  'question: What do nuclear power plants heat to generate electricity?',
#  'question: What do some broadcasts that are encrypted do not require?',
#  'question: What is a very important resource in analyzing computational problems?',
#  'question: Who is the University of Chicago accredited by?',
#  "question: When was Warsaw's first stock exchange established?",
#  'question: When did PLoS Pathogens publish a paper?',
#  'question: How many Africans were treated during the slave trade?',
#  'question: What basin does the wind blow over?',
#  'question: What battle did William II of Normandy kill King Harold II?',
#  'question: How do algorithms scale?',
#  'question: What is the principle of non-discrimination?',
#  "question: What was the Court of Justice's ruling in Steymann v Staatssecretaris van Justitie?",
#  'question: What is fast but has a small probability of error?',
#  'question: Who was the British Landgrave?',
#  'question: Where do ctenophores pump water from brackish water?',
#  'question: What is released in combustion from oxygen?',
#  'question: Asia and what other region were added to the British Empire in the 19th century?',
#  'question: When was proportionality recognized by the European Court of Justice?',
#  'question: Where was the two-volume illustrated folio paraphrase version printed?',
#  'question: Why are most lakes emptied before winter?',
#  "question: What is imperialism used to describe one's superiority, domination and influence upon?",
#  'question: What is the main difference between community pharmacies and Internet pharmacies?',
#  'question: What did the Court of Justice hold was unjust?',
#  'question: What is the main constituent of lifeforms?',
#  'question: What is the detailed treatment of the connection between macroscopic nonconservative forces and microscopic conservative forces?',
#  'question: What happens to errant members?',
#  'question: When did the Pleistocene end?',
#  'question: What did France concentrate its forces against?',
#  'question: Where has the IPCC correctly quoted the date of 2035?',
#  'question: How long has the area of Jacksonville been inhabited?',
#  'question: When did the British capture Fort Beauséjour?',
#  'question: What is an indicator for the effects of taxation?',
#  'question: What did the Tower Theatre show in the 1970s?',
#  'question: When are the warmest months in Jacksonville?',
#  'question: What type of force is not there?',
#  'question: What is the busiest commercial port in the US?',
#  'question: What can stratigraphers locate areas for?',
#  'question: Where is the famous rock Lorelei located?',
#  "question: What is Brazil's position in the world for soybeans?",
#  'question: Why was Interstate 5 built on the west side of the Central Valley?',
#  'question: What is the process of gaining steam?',
#  'question: What is the strategy of Islamization of society seized by?',
#  'question: When did the plague first arrive in Norway?',
#  'question: What do some civil disobedients believe is incumbent upon them to accept punishment?',
#  'question: Who observes the fabric within rocks?',
#  "question: What fossil is from China's Chengjiang lagerstätte?",
#  'question: What imports became mass-market leaders?',
#  'question: What area of Jacksonville had difficulty getting municipal services?',
#  'question: What can oxygen gas be produced by electrolysis of water into?',
#  'question: Who was chairman of the House Science Committee?',
#  'question: How many classes did the Yuan society eventually become?',
#  'question: Who invited Huguenots to settle in Brandenburg?',
#  'question: What is the most basic Turing machine?',
#  'question: What is the difference between the President and Commissioner of the ECB?',
#  'question: When did the center in Hong Kong open?',
#  'question: What type of cycles did the disparity between the wealthiest citizens and the rest of the nation cause?',
#  'question: What is an example of a function problem?',
#  'question: What can graphs be encoded directly via?',
#  'question: What is the name of the Transpacific Yacht Race?',
#  'question: Who was a lithium-ion battery developer?',
#  'question: What is the rotational equivalent for position?',
#  'question: What climate may have allowed the tropical rainforest to spread across the continent?',
#  'question: Where did the actual temperature rise occur over the six years studied?',
#  'question: What type of agency is the head of government acting in?',
#  'question: During what period did Jacksonville become popular winter resorts for the rich and famous?',
#  'question: Brownlee believes civil disobedience is only justified against what?',
#  'question: Who applies European Union law?',
#  'question: How many customers does Sky UK Limited have?',
#  'question: What is the angle of the pistons in a double expansion group?',
#  'question: How many metres of building material per hour are printing as of January 2013?',
#  'question: What has Citizenship of the EU increased?',
#  'question: What theory formed a supposedly rational justification for imperialism?',
#  'question: What did the development of the fertile soil allow in the previously hostile environment?',
#  'question: What did Galileo conclude motion in a constant velocity was completely equivalent to?',
#  'question: Why did Loudoun leave Fort William Henry?',
#  'question: What was the value of the dollar left to do?',
#  'question: Who invaded Afghanistan?',
#  'question: When did Rajendra K. Pachauri resign?',
#  'question: What type of civil disobedience makes it harder for a system to function?',
#  'question: Where does newly created wealth concentrate?',
#  'question: What is the extra compact filament thought to have?',
#  'question: Who disputed the concept of conscience vs. the collective?',
#  'question: What was the term for people living in tropical environments?',
#  'question: How did users connect to Tymnet?',
#  'question: When did Republicans become supportive of the French empire?',
#  'question: What village was the home of the Old Briton?',
#  'question: What organization has the Historical and Critical Dictionary become a foundational text?',
#  'question: What is the typical speed of a steam turbine in the USA?',
#  'question: What group of Muslims were actually agents of the West serving Western interests?',
#  'question: What type of delta is the Rhine-Meuse Delta?',
#  'question: What does LeGrande describe the student of civil disobedience?',
#  "question: What is the state's largest non-Christian religion?",
#  'question: Who is a Fields Medalist?',
#  'question: What type of transport appliance was used to propel machinery?',
#  'question: What areas of Jacksonville had difficulty getting municipal services?',
#  'question: What is associated with higher levels of inequality?',
#  'question: What does the HT take about Muslim history?',
#  'question: What was the name of the governor of Samarqand?',
#  'question: Who wrote Knowledge and Decisions?',
#  'question: What is the lowest bound of T(n)?',
#  'question: Who was a professor at the University of Paris?',
#  'question: Who disliked the affiliation?',
#  'question: Who condemned the Spanish Inquisition?',
#  'question: When did the Huguenot community begin?',
#  'question: What does the Presiding Officer try to achieve when selecting members to speak?',
#  'question: What people originally lived in Jacksonville?',
#  'question: What do major events play a big part in in Victoria?',
#  'question: Who determines invitations to address Parliament?',
#  'question: What river is Harvard Stadium located across from?',
#  'question: What were Huguenots called when they stayed in France?',
#  'question: When did Möngke Khan die?',
#  'question: What type of rock is a sedimentary rock?',
#  'question: What were the two main treaties that form the European Union?',
#  'question: What did Céloron do to Old Briton?',
#  "question: What type of engine did Watt's engine produce?",
#  'question: What does Siebengebirge mean?',
#  'question: What is the Rhine Gorge known for?',
#  'question: What would happen if 1 were considered a prime?',
#  'question: What is not civil disobedience?',
#  'question: What is the goal of the capabilities approach?',
#  'question: What was the name of the American foreign policy that Butler criticized?',
#  'question: What force is applied to an object suspended on a vertical spring scale?',
#  'question: Antigens bind to what?',
#  "question: Who introduced an ingenious improvement of Savery's construction?",
#  'question: What is the other form of oxygen?',
#  'question: What is the result of a reduction?',
#  'question: What are the default emission factors used to derive emissions estimates based on?',
#  "question: What years did OPEC's price increase?",
#  'question: How high is the Alpine Rhine?',
#  'question: What type of schools are considered independent?',
#  'question: What is the punishment for a lawbreaker?',
#  'question: What do stable and radioactive isotope studies provide insight into?',
#  'question: What type of electricity must be used to produce hydrogen and oxygen?',
#  'question: What percentage of the student population is private school in New Zealand?',
#  'question: What is ripped up and deposited in a newer layer of sedimentary rocks?',
#  'question: What is the final stage of the bill?',
#  'question: What is malum in se considerations?',
#  'question: What does the Islamic State lack in international recognition?',
#  'question: What ratio of radioactive elements is measured in minerals?',
#  'question: What is the name of the medicine that uses special oxygen chambers?',
#  ...]

# %%
targets
# Out:
# ['question: According to the AAA, what is the percentage of the gas stations that ran out of gasoline?',
#  'question: The restriction modification system is used by bacteria for protection from what pathogens?',
#  'question: Which team was suspended from the MLS?',
#  'question: Where was Dyrrachium located?',
#  'question: What encouraged trade under the Yuan?',
#  'question: What value does the seperating into fermions and bosons depend?',
#  'question: What nominal title did Yuan emperors have?',
#  'question: What type of compounds such as acetone,contain oxygen?',
#  'question: What is unique about a hermaphrodite?',
#  'question: What are the independant components of a vector sum that has been determined by scalar addition of individual vectors?',
#  'question: Who did Dinwiddie order to address French in Virginia territory?',
#  'question: Who invited Washington to dine with him?',
#  'question: WHat does UserDatagram Protocol gaurentee',
#  'question: How many tons of Saharan dust falls on the Amazon Basin each year?',
#  'question: When did oil start getting priced in the terms of gold?',
#  'question: In local Alemannic dialect, what is the the singular form of the names of the islands formed by the Rhine?',
#  'question: What sin were the leaders the extremists attacked guilty of?',
#  'question: What percentage of private school students go to Catholic schools?',
#  'question: What did Baran develop during research at RAND',
#  'question: In what year was the school renamed as Harvard College?',
#  'question: What type of surveys show the location of stratigraphic units in the subsurface?',
#  'question: What rift system developed in the Alpine orogeny?',
#  'question: What contributed to the severity of the plague?',
#  'question: During withdrawal from Fort William Henry, what did some Indian allies of French do?',
#  'question: Higher rates of health and social problems are just two of examples of effects from what?',
#  'question: What French City was New Rochelle named after?',
#  'question: What did the Gulf War inadvertently do in the early 1990s?',
#  'question: At first, what did oxygen and iron combine to form?',
#  'question: What is included in Medication Therapy Management?',
#  'question: How much was the combined wealth of the "10 Million dollar millionaires" in 2008?',
#  'question: Why should disobedience by the general public be avoided?',
#  'question: What is the force between two locations related to?',
#  'question: What does the IPCC not do?',
#  'question: What is the name of the co-ed community service fraternity?',
#  'question: Which parts of the Earth are included in the lithosphere?',
#  'question: What type of outcomes can even stable markets lead to?',
#  'question: Who was the most influential researcher among those grappling with the deficit of work surrounding the complexity posed by algorithmic problems?',
#  'question: What did frozen subsoil and expanded alpine glaciers begin to do?',
#  'question: Who recorded "Walking in Fresno?"',
#  'question: What concept did philosophers in antiquity use to study simple machines?',
#  'question: What supplanted Frame Relay and X.25',
#  'question: In what interval are some of the greatest primes without a distinct form discovered in?',
#  "question: What is one example of what a clinical pharmacist's duties entail?",
#  'question: In what year did the university first see a drop in applications?',
#  'question: In the layered model of the Earth, the outermost layer is what?',
#  'question: Who is credited with finding evidence of large settlements in the Amazon forest?',
#  'question: What can concentrated oxygen produce?',
#  'question: In what sector are jobs beginning to decrease?',
#  'question: How did the Better Jacksonville Plan generate money?',
#  'question: Which country was thinking about going to war to forcibly take Middle Eastern oil fields?',
#  'question: What helps the process of free movement of goods?',
#  'question: What reason is given that you should also protest public companies?',
#  'question: What was the price of oil in March of 1974?',
#  'question: What naval battles did France lose in 1759?',
#  "question: What happens secondly if a Directive's deadline is not met?",
#  "question: What was the name given to the undergraduate college's liberal-arts curriculum?",
#  'question: A problem set that that is hard for the expression NP can also be stated how?',
#  'question: According to the theory, what does the name "Huguenot" mean?',
#  'question: What kinds of sciences were Social Darwinism and theories of race?',
#  'question: How many seats does Victoria have in the Senate?',
#  'question: What is the jelly-like susbtance called?',
#  'question: What were the two main theories of immunity at the end of the 19th century?',
#  'question: What class is most commonly not ascribed to the graph isomorphism problem in spite of definitive determination?',
#  'question: When the three types of rock are re-melted what is formed?',
#  "question: What may be possible for multiple Kuznets' cycles to be in at any given time?",
#  'question: Helper and regulatory T cells can only recognize antigens coupled to what kind of molecules?',
#  'question: Tribal members living in the rainforests of what region are using Google Earth?',
#  "question: What policy did Stalin implement shortly after Lenin's Death?",
#  'question: Who made Ralph earl?',
#  'question: Which entities were originally concerned with preventing violation of human rights?',
#  "question: When was Kublai's administration running out of money?",
#  'question: When were Joseph Schumpeter and Norman Angell at their most prolific writing period?',
#  'question: WHy was the Merit network formed in Michigan',
#  'question: What type of engines became popular for power generation after piston steam engines?',
#  'question: NP complete problems contain the lowest likelihood of being located in what problem class?',
#  'question: What is another type of public key cryptography algorithm?',
#  'question: When was there an attempt to reform the law of the EU?',
#  'question: What is the complex "two-signal" activation of T cells referred to?',
#  'question: What are the two primary constitutional sources of the European Union?',
#  'question: What is the prize offered for finding a solution to P=NP?',
#  'question: What civilization was the first known to clearly study prime numbers?',
#  'question: What is the typical working fluid in a steam engine?',
#  'question: When are the new Sky Q products going to be available?',
#  'question: How many scientists called to change the IPCC in Feb 2010?',
#  'question: What do Cydippids use to capture their prey?',
#  'question: What 3 things does the Air Force work key on',
#  'question: Who normally instructs members how to vote?',
#  'question: What kind of company is Sky UK Limited?',
#  'question: During what time period did income inequality decrease in the United States?',
#  'question: What kind of interethnic marriage became common in the Jin dynasty?',
#  'question: What is the most likely effect of breathing oxygen?',
#  "question: The Brotherhood's members are against consuming what beverage?",
#  'question: Problems capable of theoretical solutions but consuming unreasonable time in practical application are known as what?',
#  'question: What part of France were the Normans located?',
#  'question: What organization argued that drought, among other effects, could cause the Amazon forest to reach a "tipping point?"',
#  'question: What measure of a computational problem broadly defines the inherent difficulty of the solution?',
#  'question: Peroxides, nitrates and dichromates are examples of what type of compounds?',
#  'question: What is the axis of Warsaw which divides it into two parts?',
#  'question: How is income determined in a market with variously skilled workers?',
#  'question: Time and space are both examples of what type of resource?',
#  'question: What aspect of Western medicine did the Chinese dislike?',
#  'question: What kind of interethnic marriage became common in the Jin dynasty?',
#  'question: What are the two major subsystems of the immune system?',
#  'question: What often affects or facilitates ease of analysis in computational problems?',
#  'question: Who was made Governor of Samarqand?',
#  'question: How far from the Yard is the Quad located?',
#  'question: What ethnic group located in Jacksonville is ranked tenth largest?',
#  'question: What elements from the rift system in the Alpine orogeny in Southwest Germany?',
#  'question: When Iqbal promoted ideas of greater Islamic political unity, what did he encourage ending?',
#  'question: What value does the seperating into fermions and bosons depend?',
#  'question: The prospect of what event compelled the protection of German private schools?',
#  'question: What part of the innate immune system identifies microbes and triggers immune response?',
#  'question: Why has Warsaw seen many improvements over the past decade?',
#  'question: What did Joseph Haas say in his email?',
#  'question: What can sympathetic Jurors in cases with civil disobedients?',
#  'question: How many bits are often in the primes used for RSA public key cryptography algorithms?',
#  'question: What order did British make of French?',
#  'question: Where does the Delta in the Netherlands begin?',
#  'question: What does the bolinopsis generally eat?',
#  'question: In what century did the history of the steam engine begin?',
#  'question: What spurred increased support for government reform?',
#  'question: What is the natural dam that the Rhine flows through?',
#  'question: What is the medieval Esteve Pharmacy used as at present?',
#  'question: The region spans which mountains other than the Transverse ranges?',
#  'question: How many times more did the other nations have to pay for oil after the surprise attack?',
#  'question: What is the goal of the capabilities approach?',
#  'question: What is stratigraphy?',
#  'question: What did the increase in skilled workers lead to?',
#  'question: Who killed Harold II?',
#  'question: Was was the plan for Langlades mission?',
#  'question: Who noted the different current uses of civil disobedience?',
#  'question: What did the Edict do for Huguenots in France?',
#  'question: What is the name for O3 most often used?',
#  'question: What does a receiver have to be equipped with to view encrypted content?',
#  'question: What was the first steam powered device used commercially?',
#  'question: What is stratigraphy?',
#  'question: What is an example of major civil disobedience in South Africa?',
#  'question: What type of combustion does the slow reaction of triplet oxygen prevent?',
#  'question: What financial issue is notoriously prevalent in the construction field?',
#  'question: What rate of unionization do Scandinavian nations have?',
#  'question: What is resposible for speeding up or slowing down an object?',
#  'question: Prior to the arrival of the French, the area now known as Jacksonville was previously inhabited by what people?',
#  'question: What happened with the rate of flow in the Rhine with the straightening program?',
#  'question: What is most of the cleared land in the Amazon region used for?',
#  'question: Who wrote about the great pestilence in 1893?',
#  'question: What disagreement did Montcalm and Indians have?',
#  'question: What is the term for wind-blown dust in a tundra?',
#  'question: What is a typical configuration',
#  'question: What event was the worst example of Huguenot persecution?',
#  "question: How far apart are some of the neighborhood's features?",
#  'question: Was the Use of the DATANET 1 name correct',
#  'question: In what way do idea strings transmit tesion forces?',
#  'question: Pneumatica was written by what Greek writer?',
#  'question: Brownlee argues disobedience can be justified toward what institutions?',
#  'question: Why has Warsaw seen many improvements over the past decade?',
#  'question: What was the result of the disobedience protesting the nuclear site?',
#  'question: How did the principle treaties that form the European Union begin?',
#  'question: What did Lindzen criticize about the Summary for Policymakers?',
#  'question: What lab does the university have a joint stake in?',
#  'question: Why does unemployment harm growth?',
#  'question: What is an example of a problem that rests within the NP complexity class?',
#  'question: When did the Chinese famine begin?',
#  'question: What is the area called near the Rhine Gorge with castles from the middle ages?',
#  'question: How many auricles do most species have?',
#  'question: Which historic empire used cultural imperialism to sway local elites?',
#  'question: Which Treaty protects the freedom of establishment and the freedom to provide services?',
#  'question: Cilia can g ow up too what length?',
#  'question: What academy did Tugh Temur found?',
#  'question: In what year was the school formed?',
#  'question: Is the Lisbon Treaty one that would alter existing treaties or replace them?',
#  'question: What magnitude of earthquake can many faults produce?',
#  'question: What bacteria lives inside a protective capsule that serves to prevent cell lysis?',
#  'question: Who was appointed as second in command to Lor Loudoun in 1756?',
#  'question: Along with mills and mines, in what industrial locations did steam drive machines?',
#  'question: What is the largest suspension bridge in Germany?',
#  'question: What platform caused BSkyB to end their analogue service?',
#  'question: What is the name of the border to the south?',
#  'question: What areas are pharmacy informatics prepared to work in?',
#  'question: What percentage of electricity was made by steam turbine in the 1990s?',
#  'question: Refineries, process chemical, power generation, mills and manufacturing plants are under what sector of construction?',
#  'question: What did Donald Davies Develop',
#  'question: What modern formations do geologists study?',
#  'question: What are examples of differentiated effector cells that peak during wake periods?',
#  'question: Why do the island archipelagos comprise a smaller number of electors?',
#  'question: What term is shorthand for antibody generators?',
#  'question: Where are health and social problems most common?',
#  'question: What is blamed for causing the sharp drop in fish catches in the Black Sea and the Sea of Azov?',
#  'question: Recent studies believe that ctenophores are the sister lineage to what?',
#  'question: The defeat of the Arab troops in the Six-Day War constituted what for the Arab Muslim world?',
#  'question: Why does a lower level of economic growth occur due to high-end consumption?',
#  'question: The Central Pacific Railroad established a station for its new line in what year?',
#  'question: What delivery message was used',
#  'question: What is the longest river in Germany?',
#  'question: What type of insect employs the use of prime numbers in its evolutionary strategy?',
#  'question: What are the total number of votes to be counted during the voting process?',
#  'question: Data from physical experiments can be extrapolated to the field to understand what processes?',
#  'question: How many bits are often in the primes used for RSA public key cryptography algorithms?',
#  'question: What were blank spaces used for on nineteenth-century maps?',
#  'question: The presence of who is highly likely even in small projects?',
#  'question: It is now possible to convert old relative ages into what type of ages using isotopic dating?',
#  'question: What did Mitsubishi rename its Forte to?',
#  'question: What is the Rankine cycle sometimes called?',
#  'question: What organization has continued to be a major disruptive force in Palestine?',
#  'question: What is a PPP also known as?',
#  'question: How much retail activity does the neighborhood have?',
#  'question: Where is the principle of proportionality recognized in the EC treaty?',
#  'question: Other than L.A. which other county do many people commute to?',
#  "question: What did 'Da Yuan Tong Zhi' mean?",
#  'question: What type of immune systems are found in all plants and animals?',
#  'question: Who did the Dutch fight in the Dutch Revolt?',
#  'question: What did Kublai do to prevent famines?',
#  'question: What is the medieval Esteve Pharmacy used as at present?',
#  'question: What type of actions are taken sometimes in civil disobedience?',
#  'question: On what river does Warsaw stand?',
#  'question: Who did Abercrombie replace as commander in chief?',
#  'question: Who is given credit for discovering geoglyphs along the Amazon River?',
#  'question: What was the memoir entitled which was submitted to the American Philosophical Society?',
#  'question: What is the primary goal of pleading not guilty when arrested for Civil Disobedience?',
#  'question: What did Mote think the Yuan class system really represented?',
#  'question: What denomination is associated with Saint Kentigern College?',
#  'question: What leads to lower income inequality?',
#  'question: Who did BSkyB team up with because it was not part of the consortium?',
#  'question: What is structural geology?',
#  'question: When dating rocks, what is the absolute isotopic date applied to?',
#  'question: How long has the Rhine coastline been in the same location?',
#  'question: What area of Brookhaven is still known for its high levels of crime?',
#  "question: What is another word for the Earth's upper mantle?",
#  "question: Who funds the IPCC's Secretary?",
#  'question: When did the last glacial end?',
#  'question: Assuming that T represents a polynomial in T(n), what is the term given to the corresponding algorithm?',
#  'question: Constructing a project that fails to adhere to codes does not benefit whom?',
#  'question: What are colonial powers blamed for?',
#  'question: Where did France focus its efforts to rebuild its empire?',
#  'question: Which organic compounds contain the greatest amount of oxygen by mass?',
#  'question: What is the average discharge of the Moselle to the Rhine?',
#  'question: What did Lindzen criticize about the Summary for Policymakers?',
#  'question: What is more fundamental than force in quanton field theory?',
#  'question: Outside of its use of automobiles, what else is southern California famous for using?',
#  'question: By which year did the American cars mpg start to improve?',
#  "question: How much of Warsaw's population was Jewish?",
#  'question: What is the weight of a bushel of coal in pounds?',
#  'question: Compared to other Australian cities, what is the size of Melbourne?',
#  'question: What law connects relative velocities with inertia?',
#  'question: For how long did the plague stick around?',
#  'question: On what type of exponentiation does the Diffie–Hellman key exchange depend on?',
#  'question: What does an increase in the income share of the bottom 20 percent of people of a society result in?',
#  'question: Where are Jersey and Guernsey',
#  'question: Where is Bielany Forest located?',
#  'question: Where is the lowest point of Warsaw located?',
#  'question: What percentage of Victorians are Christian?',
#  'question: Why was the Rhine measurement changed?',
#  'question: What is the name of the professional skateboarder that lives in southern California?',
#  'question: Where does centripetal force go?',
#  'question: When did French Republicans back building the French empire?',
#  'question: What theory was arrived at in 1811 that presented the assumption of diatomic molecules?',
#  'question: Who applies European Union law?',
#  'question: Which regions have temperate climates?',
#  'question: What is the name for a form of oxygen in which electrons are paired?',
#  'question: From where would scientists like measure vegetation radiance?',
#  'question: What is the gender income inequality in Bahrain?',
#  'question: What was AUSTPAC',
#  'question: Who started the IPCC Trust Fund?',
#  'question: What do capitalist firms substitute equipment for in a Marxian analysis?',
#  'question: How else might a physician take advantage of self-interest?',
#  'question: How much dust is blown out of the Sahara each year?',
#  "question: Roughly how much is the Student Government's budget?",
#  'question: What happens to the lead fusible plugs if the water level of the boiler drops?',
#  'question: What characteristic of oxygen makes it necessary to life?',
#  'question: What type of civil disobedience is accompanied by aggression?',
#  'question: When did the Jin dynasty begin?',
#  'question: How much money was Francovich allowed to claim from the Italian goverment in damages?',
#  'question: What made Ohio Country vulnerable?',
#  'question: What do platyctenida use their pharynx for?',
#  "question: Southern California's distinctive regions are divided culturally, politically and what other trait?",
#  'question: How many tons of carbon are absorbed the Amazon in a typical year?',
#  'question: Rudyard Kipling was an influential spokesman for what?',
#  'question: What did BSkyB name their interactive service?',
#  'question: Who was Ralph in charge of being at war with?',
#  'question: How far is Warsaw from the Baltic Sea?',
#  'question: Western Imperialism divided the globe according to which theory?',
#  'question: Who provides the bill of quantities?',
#  'question: How successful was initial effort by Braddock?',
#  'question: What is the name for O3 most often used?',
#  "question: What is the UN's climate change treaty?",
#  'question: Did the plague spread in Scandinavia or Germany first?',
#  'question: When was the Masovian Duchy reincorporated into the Polish Crown?',
#  'question: Who are debates and meetings open to?',
#  'question: What set the stage for Merits role in NSFNET',
#  'question: What can keep an object from moving when it is being pushed on a surface?',
#  'question: Why is it important to precisely date rocks within the stratigraphic section?',
#  'question: What is also decided by the Presiding Officer?',
#  'question: When did the European Council task an entity with drafting a European Charter of Human Rights?',
#  'question: What is another notable university in Warsaw after the University of Warsaw?',
#  'question: What was the Plos Pathogens paper about?',
#  'question: What kind of forest is the Amazon rainforest?',
#  'question: What drew would-be Jacksonville tourists to other Florida destinations?',
#  'question: Bounding of time and space or similar measurements is often used by algorithms to define what?',
#  'question: When did the Egyptian Islamic Jihad assassinate Anwar Sadat?',
#  'question: What stretched across middle Europe in the last ice age?',
#  'question: When would a person be considered to be excising a constitutional impasse?',
#  'question: What enzymes in saliva are antibacterial in nature?',
#  "question: What does the EU's legitimacy rest on?",
#  'question: What was another term used for the oil crisis?',
#  'question: What was the period called that was 505 million years ago?',
#  'question: What type of microscope is used by petrologists?',
#  'question: Where is the lowest point of Warsaw located?',
#  'question: Who did the Parliament rent additional buildings from?',
#  'question: In Sept 1760 who negotiated a capitulation from Montreal?',
#  'question: Why should disobedience by the general public be avoided?',
#  'question: Colonialism often means a country doing what?',
#  'question: What function does ozone perform for the planet?',
#  'question: According to Lenin why must capitalistic countries have an imperialistic policy?',
#  'question: What is the confusion of the French and Indian war?',
#  'question: Jules Ferry thought that the "higher races" have a duty to what?',
#  'question: What gave Priestley the claim to being the first discovered of oxygen?',
#  'question: What does it mean for a disease to be enzootic?',
#  'question: What additional benefits are there to surrounding community of expansion?',
#  'question: Why did natural sedimentation by the Rhine compensate the transgression bby the sea?',
#  'question: the Great Internet Mersenne Prime Search, what was the prize for finding a prime with at least 10 million digits?',
#  'question: What equation currently decribes the physics of force.',
#  'question: Who pays Australian pharmacists for doing Home Medicines Reviews?',
#  'question: What makes ctenophores different from all other animals?',
#  'question: What is KMJ now referred to?',
#  'question: What provided much of the basis for the structure of the Parliament in 1995?',
#  'question: What is another word for centripetal force?',
#  'question: What is set aside for question periods in the debating chamber?',
#  'question: Why is the final bill passed to the Monarch?',
#  'question: What provided much of the basis for the structure of the Parliament in 1995?',
#  'question: What does a U.S. census report state that even after other factors there still exists this between earnings of men and women?',
#  'question: Combs are called what?',
#  'question: The oil crisis caused oil companies to increase oil supplies in which area?',
#  'question: What year did BSkyB and Microsoft announce their settlement?',
#  'question: In which region tribe were large settlements discovered?',
#  'question: When was the heatwave in which Hopetoun recorded its highest temperature?',
#  'question: What type of interpretation of Islam does Salafism promote?',
#  'question: What happens after the lead melts?',
#  'question: Who has design authority over all of the digital satellite receivers that are capable of using their service?',
#  'question: Stretched rocks that pinch into lenses are known by what word?',
#  'question: The complexity of problems often depends on what?',
#  'question: What are private secondary schools in Germany called?',
#  'question: How many tons of dust are blown from the Sahara each year?',
#  'question: What is the problem attributed to defining if two finite graphs are isomorphic?',
#  'question: Who is the President of Egypt?',
#  'question: Recent studies believe that ctenophores are the sister lineage to what?',
#  'question: In what country can most of the Amazon rainforest be found?',
#  'question: Sedimentary rock can be turned into which of the three types of rock?',
#  'question: When was the Special Report on Renewable Energy Sources and Climate Change Mitigation (SRREN) issued?',
#  'question: In some countries over how many steps can it take to build on government land?',
#  'question: After what battle did Union forces return to and occupy Jacksonville for the rest of the war?',
#  'question: Who was Iqbal a critic of?',
#  'question: What religions did Tugh Temur follow?',
#  'question: What does the time element in construction mean?',
#  'question: When did the series of strikes happen?',
#  'question: What instrument is used to examine steam engine performance?',
#  'question: How does the level of tuition in German private schools compare to private schools in other Western European countries?',
#  'question: How is unregistered property held in informal form?',
#  'question: What type of hermaphrodite produces egg and sperm at different times?',
#  'question: What causes the population of ctenophora to grow at an explosive rate?',
#  'question: Which historic empire used cultural imperialism to sway local elites?',
#  'question: Which court is the highest court in the European Union?',
#  'question: What causes triplet oxygen to react slowly?',
#  'question: What is an underbid?',
#  'question: What does factorization of prime ideals approximate?',
#  'question: By what means were scientists able to liquefy air?',
#  'question: What is the concrete choice typically assumed by most complexity-theoretic theorems?',
#  'question: Which tribes did Genghis Khan unite?',
#  "question: How long did it take for Thoreau's disobedience to be known?",
#  'question: The owner typically awards a contract to who?',
#  'question: What was Joseph Haas arrested for?',
#  'question: What helps the process of free movement of goods?',
#  'question: When was Zhu Shijie born?',
#  'question: What does the WG I Summary for Policymakers report say human activities are doing to greenhouse gases?',
#  'question: What was the UK governments benefits agenchy checking in 2012?',
#  'question: According to certain Geographical theories what type of human does a tropical climate produce?',
#  'question: Which part of the immune system protects the brain?',
#  'question: The freedom to provide services under TFEU article 56 applies to who?',
#  'question: How did Celeron feel about Native relations?',
#  'question: What did ITV increase their yearly offer for control of the rights to broadcast the Primer League to?',
#  'question: What is as important as identifying plague symptoms?',
#  'question: When did BSkyB discontinue the Sky+ Box?',
#  'question: What is used to quantify the intuitive undestanding of forces?',
#  'question: What are environmentalists concerned about losing in the Amazon forest?',
#  'question: What did Gou use for astronomy?',
#  'question: Why has the Muslim Brotherhood facilitated inexpensive mass marriage ceremonies?',
#  'question: How many casualties did British get?',
#  'question: What movements pursued a more radical direction?',
#  'question: What social construct did Huguenot refugees in Canterbury practice?',
#  'question: Along with a desire for more steam pressure, what were early drivers looking to generate when they fastened safety valves down?',
#  'question: Many construction companies are now placing more emphasis on what?',
#  'question: What is the immune system of the brained known as?',
#  'question: What range of years was the current warming compared to?',
#  'question: Combustion is caused by an oxidant and a fuel. What role does oxygen play in combustion?',
#  'question: Why did the university eventually leave the conference?',
#  'question: How many degrees south did the Amazon rainforest reach from 66-34 Mya?',
#  "question: What material's weight gain during rusting was an early clue that philogiston theory was wrong?",
#  'question: How did Saint-Pierre respond to Washington?',
#  'question: Concrete bounding of computation time frequently produces complexity classes contingent upon what?',
#  'question: The rate of clearing of forest from 2000 to 2005 was how many square miles per year?',
#  'question: When was the confederation of the Rhine?',
#  'question: What law staes that forces are interactions between bodies?',
#  'question: How do ctenophores control buoyancy?',
#  'question: What is the confusion of the French and Indian war?',
#  'question: What comedian is also a university graduate?',
#  'question: In what complexity class do complement problems of NP problems exist?',
#  'question: What army was pushing deep into Polish territory to pursue the Germans in 1944?',
#  'question: What UN organizations established the IPCC?',
#  'question: How long is the section of the Rhine near Chur?',
#  "question: What public policy school found it's home in the building that Ludwig Mies van der Rohe designed?",
#  'question: At what degree are the pistons of a two-cylinder compound connected to the cranks?',
#  'question: When was the European Convention on Human Rights established?',
#  'question: What present-day company did BankAmericard turn into?',
#  'question: During which years was no census taken?',
#  'question: What is a very seldom used unit of mass in the metric system?',
#  'question: What is the second busiest container port in the United States?',
#  'question: How could human inequality be addressed without resulting in an increase of environmental damage?',
#  'question: Who provides the bill of quantities?',
#  'question: Name one way the Plowshares organization temporarily close GCSB Waihopai?',
#  'question: What is the name of the first aviation community built?',
#  'question: Where were interviews held while the parliament was in its temporary building?',
#  'question: In what constituent country of the United Kingdom is Merthyr Tydfil located?',
#  'question: What kind of representational system does the Victorian Legislative Council have?',
#  'question: What is the field of studying immunogenicity through bioinformatics known as?',
#  'question: What does the acronym FIS stand for?',
#  'question: What South African Vice Consul did Harvard students blockade the speech of?',
#  'question: When did the Meuse and Waal merge?',
#  'question: What mechanism moves coal from a bunker to the firebox?',
#  'question: How do bills pass through Parliament?',
#  'question: How many tons of dust are blown from the Sahara each year?',
#  'question: What must the integer m be less than or equal to when performing trial division?',
#  'question: What type of number do modern mathematicians consider 1 to be?',
#  'question: What status has the Brotherhood obtained in the Islamic world?',
#  'question: Why might rats not be responsible for the plague?',
#  "question: What was William Johnson's role in British military?",
#  'question: Where did Iroquois Confederation control?',
#  "question: What's the party's take on Muslim history?",
#  'question: Which conjecture holds that for any positive integer n, there is an infinite amount of pairs of consecutive primes differing by 2n?',
#  'question: What difficulties was Shirly having?',
#  'question: What is the name for a form of oxygen in which electrons are paired?',
#  "question: What can the IPCC's report deadlines cause to be omitted?",
#  'question: What year did BSkyB and Microsoft announce their settlement?',
#  'question: What type of numbers demonstrate a flaw with the Fermat primality test?',
#  'question: What was a non-religious reason for the massacre?',
#  "question: When was Thoreau's essay published?",
#  'question: What else was used by pharmas?',
#  'question: What would someone who is civilly disobedient do in court?',
#  'question: In what battle were the Mongols defeated by the Tran?',
#  'question: What writing inspired the name Great Yuan?',
#  'question: What are the three primary expressions used to represent case complexity?',
#  'question: What is the observable effect of W and Z boson exchange?',
#  'question: How quickly can an algorithm solve an NP-complete knapsack problem?',
#  'question: Who owns the rail lines in Victoria?',
#  'question: What did the Merwede-Oude Maas form with Waal and Lek?',
#  'question: Where did Maududi exert the most impact?',
#  'question: Where can the entire sedimentary sequence of the Grand Canyon be seen in less than the length of a meter?',
#  'question: What event would necessitate airline passengers to need a supplemental supply of oxygen?',
#  'question: What choice did French have for surrendering land?',
#  'question: Why are newly discovered oil sold at a higher price?',
#  'question: bassett focuses on what to illustrate his idea?',
#  'question: What type of climate does Jacksonville have?',
#  'question: What set is a seat added to after being allocated?',
#  'question: According to Lenin why must capitalistic countries have an imperialistic policy?',
#  'question: What other reason caused poor supply of New France from a difficult winter?',
#  'question: Which genus lack tentacles and sheaths?',
#  'question: Which Count did the Prince strike an arrangement with?',
#  'question: Friedrich Ratzel thought imperialism was what for the country?',
#  'question: What medical treatment is used to increase oxygen uptake in a patient?',
#  'question: How populous is Victoria compared to other Australian states?',
#  'question: Who deployed its army into Afghanistan in 1979?',
#  'question: Where is the coldest section of Victoria?',
#  'question: Who operated the vBSN network',
#  'question: What covered Scandinavia, the Baltics, Scotland, and the Alps in the last Ice Age?',
#  'question: Post 2008 undergraduate students are required to complete how many general education classes towards degree?',
#  'question: The Yuan was the first time all of China was ruled by whom?',
#  'question: When did Western forces invade Iraq?',
#  'question: In what city is the last Huguenot congregation in the US?',
#  'question: Who designed the Scottish Parliament building?',
#  "question: What does Warsaw's mixture of architectural styles reflect?",
#  'question: Where was there a weakness in British supply chain?',
#  'question: Who has the power to initiate legislation within the European Union?',
#  'question: What did the Court of Justice say Steymann was entitled to?',
#  "question: Germany doesn't have an imperialistic past until when?",
#  'question: What is the Royal Castle the most interesting example of?',
#  'question: Why is giving a defiant speech sometimes more harmful for the individual?',
#  'question: Near Chur, which direction does the Rhine turn?',
#  'question: What person argues that civil disobedience is used to describe everything?',
#  'question: How much did the statement predict global surface temperature would increase by 2100?',
#  'question: What is the logic behind the cicadas prime number evolutionary strategy?',
#  'question: At what temperature will oxygen condense?',
#  'question: According to the theory, what does the name "Huguenot" mean?',
#  "question: What was the title of Philo's work?",
#  'question: Revolutionary civil disobedience towards culture is highlighted by example of who?',
#  'question: What was used by the West to justify control over eastern territories?',
#  'question: What is another way of referring to stators?',
#  'question: In what form is oxygen transported in smaller containers?',
#  'question: The point at which different radiometric isotopes stop diffusing into and out of the crystal lattice is called what?',
#  'question: What present day county is New Rochelle in?',
#  'question: What is the minimum percent of alcohol content a German law requires all spirits and liqueurs to have?',
#  "question: What did Iqbal's Allahabad address inspire?",
#  'question: What nationality was Arthur Woolf?',
#  'question: What combined with ricing prices to make it difficult or impossible for poor people to keep pace?',
#  'question: Strictly speaking who was included in DATANET 1',
#  'question: When did the age of imperialism end?',
#  'question: What are the three construction subsectors?',
#  'question: Who claims that public companies can also be part of civil disobedience?',
#  'question: What is the general term used to describe the output to any given input in a problem instance?',
#  'question: What have the Treaties sought to enable since its foundation?',
#  'question: Evidence indicates that Cydippids are not what?',
#  'question: What type of number generators make use of prime numbers?',
#  'question: What did AUSTPAC support',
#  'question: What percentage of Filipino tertiary education takes place in private schools?',
#  'question: What does the minister who was the catalyst of the Members Business do by speaking after everyone else?',
#  'question: What immune system is activated by the innate response?',
#  'question: What type of treatment do civil disobedients usually receive?',
#  'question: What type of number theory utilizes and studies prime ideals?',
#  'question: What was the percentage of Black or African-Americans living in the city?',
#  'question: When was the Polish-Bolshevik war fought?',
#  'question: Why did the 5th president of the university decide to get rid of the football program?',
#  'question: What equals the spring reaction force on an object suspended on a spring reaction scale?',
#  "question: Where is Polonia's home venue located?",
#  "question: Under Elie Metchnikoff's cellular theory, what cells were responsible for immune response?",
#  'question: How much of the population in the Middle East died of the plague?',
#  'question: In the layered model of the Earth there are seismic discontinuities in which layer?',
#  'question: In what century did missionaries notably establish church schools in South Africa?',
#  'question: What can increase the tension force on a load?',
#  'question: While producing oxygen, what gas does a zeolite sieve absorb?',
#  'question: What is a spark or heat to the progress of a fire?',
#  'question: What will maidens be able to predict by floating their wreaths down the Vistula?',
#  'question: Who is one prominent advocate of this theory?',
#  'question: The largest construction projects are known as what?',
#  'question: What is the process of constructing a building or infrastructure?',
#  'question: What entity owns V/Line?',
#  'question: What is the most well-known algorithm associated with the integer factorization problem?',
#  'question: What was the principle shown in The Mark of Anarchy?',
#  'question: What was invented by Savery?',
#  'question: What does the beroe do when pursuing prey?',
#  "question: Warsaw's National Museum is one of the most what?",
#  'question: What administrative division did Kublai leave unmodified?',
#  'question: When do members proceed to vote on whether they agree to the principles of the final bill?',
#  "question: Of what form is the infinite amount of primes that comprise the special cases of Schinzel's hypothesis?",
#  'question: What is needed to make combustion happen?',
#  'question: What is septicemia?',
#  'question: What are numbers greater than 1 that can be divided by 3 or more numbers called?',
#  'question: What type of goals are usually done skirting the law?',
#  'question: Jellyfish ans sea anemones belong to what phylum?',
#  'question: What other kind of sport is popular in southern California?',
#  'question: Where is the neighborhood of Sunnyside located in Fresno?',
#  'question: What happens when business underpays their workers?',
#  "question: What does the Nederrijn change it's name to?",
#  'question: When was the Rhine fully within the Holy Roman Empire?',
#  'question: Why did French feel they had right to Ohio claim?',
#  'question: When was the Tower Theatre built?',
#  'question: How tall is the Bank of America Tower?',
#  'question: What UN organizations established the IPCC?',
#  'question: When did the y. pestis reach England?',
#  'question: What is attributed to the income inequality in the United States?',
#  'question: Upon learning of a French scounting party in the area, what did Washington do?',
#  'question: Between which two streets along Kearney Boulevard were wealthy African-Americans at one time residing?',
#  'question: Why did Warsaw become the capital of the Commonwealth?',
#  'question: Was was the plan for Langlades mission?',
#  'question: What is a reason for the movement to legalize importing medicines from other countries?',
#  'question: Reduction essentially takes one problem and converts into what?',
#  'question: What is the mayor of Warsaw called?',
#  'question: What was the average duty of a low-pressure Watt engine?',
#  'question: What did the the Europeans think the peoples in the tropics were in need of?',
#  'question: What does education in an area where there is high demand for workers tend to create?',
#  'question: What type of architecture is the Palace of Four Windows an impressive example of?',
#  'question: How many member states adopted the Social Charter in 1989?',
#  'question: To what is 50 kilopascals equal?',
#  "question: Which country's cars became more highly sought after as they were more fuel efficient?",
#  'question: How many species of insects are known in the region?',
#  "question: What was Kublai Khan's relation to Ogedei Khan?",
#  'question: If the head of government refuses to enforce a decision of the highest court what terminology could be used?',
#  'question: What was the population density in 2000?',
#  'question: What was the average duty of a low-pressure Watt engine?',
#  'question: What type of assistance to out of town students is the Muslim Brotherhood known for?',
#  "question: What were the three parts of Kublai's government?",
#  'question: Where on Earth is free oxygen found?',
#  'question: What is the name of another type of prime here p+1 or p-1 takes a certain shape?',
#  'question: What do petrologists use electron microprobes in the laboratory for?',
#  'question: Where is the Rhine?',
#  'question: Where does centripetal force go?',
#  'question: When was earthenware movable type invented?',
#  'question: Juvenile platyctenids act like what?',
#  'question: What did water that flowed towards the Pacific have to flow across during the mid-Eocene?',
#  'question: When was the Duchy of Normandy founded?',
#  'question: What is Pedanius Dioscorides known for?',
#  "question: What caused Jacksonville's tourism to become less desirable at the latter half of the 19th century?",
#  'question: What percentage of oxygen is usually supplied by a medical mask?',
#  'question: Where do ctenophores be found in large numbers?',
#  'question: What are MPs unable to vote upon?',
#  'question: What campaigh did the Scottish National Party (SNP) run?',
#  'question: What dynasty came after the Yuan?',
#  'question: What is the number of plant species in economics and social interest?',
#  'question: What type of forested areas can be found on the highest terrace?',
#  'question: On what railroad was Salamanca used?',
#  'question: What Huguenot area is designated as a historical landmark?',
#  'question: How large can ctenophora grow?',
#  "question: Which party is strongest in Victoria's northwestern and eastern regions?",
#  'question: Who won the Nobel Prize in 1905?',
#  'question: How far did the sea level drop in the ice ages?',
#  'question: What is the logic behind the cicadas prime number evolutionary strategy?',
#  'question: How many of the Scottish electorate would need to for it on the referendum?',
#  'question: what was invented in 1880 that revolutionized warfare?',
#  'question: If an extraordinary election is held within less than six months before the date of an ordinary election, what does it do to the ordinary election?',
#  'question: How was the efficiency of a steam engine typically evaluated?',
#  'question: Why are debates on proposed motions by an MSP conducted?',
#  'question: What was diverted and now flows parallel to the Rhine?',
#  'question: What is an example of a pump component?',
#  'question: Who thought that applied force caused movement of an object regardless of non-zero velocity?',
#  'question: In what year did Raymond Sullivan publish a study of rudimentary sets?',
#  'question: In the fall quarter of 2014, how many students signed up for the college?',
#  'question: What were X.25 and Frame relay used for',
#  'question: How many earthquakes does southern California experience in a year?',
#  'question: At what point does oxygen toxicity begin to happen?',
#  'question: What did Kuznets argue resulted from stages of development?',
#  'question: Tension, compression, and drag are what kind of forces?',
#  'question: Who mapped the Alta Vista Tract?',
#  "question: What was the second meaning of a Chinese word for 'barracks'?",
#  "question: When did BSkyB announce it's intention to replace it's free-to-air digital channels?",
#  'question: Where is the European Court of justice likely to get inspiration from?',
#  'question: What type of medicine did Mongol shamans use?',
#  'question: How many US presidents are alumni of the school?',
#  "question: Of Warsaw's inhabitants in 1901, what percentage was Catholic?",
#  'question: What does the internal cavity contain?',
#  "question: Which dynasties' histories were officially documented during Toghun's reign?",
#  'question: What does the highest level of the Vistula plateau contain?',
#  'question: What was Tymnet',
#  'question: What amount of the worlds carbon is stored in the Amazon forest?',
#  'question: What choice did French have for surrendering land?',
#  'question: What si the comparison to sea level with the oxygen level in space suits?',
#  'question: By what document did the Huguenots confess their faith to the Portuguese in Brazil?',
#  'question: How did Hobson argue to rid the world of imperialism?',
#  'question: Where was French withdrawal to?',
#  'question: How many outputs are expected for each input in a function problem?',
#  'question: Besides Germany and Switzerland, where else is Lake Constance?',
#  "question: How is civil disobedience typically defined in connection of the citizen's?",
#  'question: What is the upper house of the Parliament of Victoria called?',
#  'question: For many years, what was the Brotherhood described as?',
#  'question: What type of professional is a Pharmacy Technician considered to be?',
#  "question: Why was Polonia relegated from the country's top flight in 2013?",
#  'question: What is issued once construction is complete and a final inspection has been passed?',
# ...
#  'question: What causes strain in structures?',
#  'question: What is the purpose of the ASER?',
#  'question: When was the heyday of secular Arab nationalism?',
#  'question: How much literature has been written regarding civil disobedience?',
#  'question: What are three examples of complexity classes associated with definitions established by probabilistic Turing machines?',
#  'question: What is an example of a pump component?',
#  'question: What was the effect of the housing crash on the region?',
#  'question: Which famous Indian took a plea and put himself at the mercy of the courts?',
#  'question: What party is favored in Bedigo and Geelong?',
#  'question: When did Tugh Temur die?',
#  'question: What is one straightforward case of a probabilistic test?',
#  'question: What co-receptor recruits molecules inside the T cell that are responsible for cell activation?',
#  'question: Besides constant flooding, why else was there regulation of the Rhine?',
#  "question: As of February 2011, how many numbers has Goldbach's conjecture been proven to?",
#  'question: Who has limited productive potential when faced with less access to education?',
#  "question: WBAI's broadcasting Some of George Carlin's comedy eventually led to what?",
#  'question: What style were the mass constructed residential blocks designed in?',
#  'question: What does ctenophore mean in Greek?',
#  "question: What was the Colonia Agrippina's original name?",
#  "question: What type of steam engine doesn't need valves to direct steam?",
#  'question: What type of numbers demonstrate a flaw with the Fermat primality test?',
#  'question: Who was Chairman of the Subcommittee on Oversight and Investigations?',
#  'question: What did NSFNET promote',
#  "question: What is the world's busiest general aviation airport?",
#  'question: By what year was selling children into slavery common among the Mongols?',
#  'question: What were the two forms of environmental determinism?',
#  'question: Under what condition is an element irreducible?',
#  'question: What magnetic and electric force acts on a charge?',
#  'question: What is a recent civil disobedience done in a group form?',
#  'question: What condition what must be satisfied in order for 1/p to be expressed in base q instead of base 10 and still have a period of p - 1?',
#  'question: Why was old oil withdrawn from the market?',
#  'question: What project did Harvard halt due to the financial crisis?',
#  'question: What are some advantages of hospital pharmacies?',
#  'question: What are auricles?',
#  "question: What is the UN's climate change treaty?",
#  'question: What garden was formally only for royalty?',
#  'question: What did Graham Twigg publish in 1984?',
#  'question: How many bodies of water makes up Lake Constance?',
#  "question: Where does a canonball dropped from the crow's nest of a ship actually land?",
#  'question: What is a regulatory factor produced by macrophages?',
#  'question: What powers does the Court of Justice of the European Union have in regards to treaties?',
#  'question: Where did a bloody civil war break out?',
#  'question: Why was there a depreciation of the industrialized nations dollars?',
#  'question: Where did British resettle many Acadians?',
#  'question: At what pressure is water heated in the Rankine cycle?',
#  'question: What will the output be for a member of the language of a decision problem?',
#  'question: To what level would the polynomial time hierarchy collapse if graph isomorphism is NP-complete?',
#  'question: What was free movement increasingly based on?',
#  'question: Why did OPEC block oil deliveries to the United States?',
#  'question: Which Belgian footballer claimed that he should be allowed to transfer from one football club to another when his contract was fulfilled?',
#  'question: What time period did the geoglyphs date back to?',
#  'question: Name an extra that was added to the production of the compacts.',
#  'question: What is the largest main branch of the Rhine?',
#  'question: The inside of a ctenophore is lined with what?',
#  'question: Other than Universal and Warner Brothers, what other company runs a major record company?',
#  'question: What are the weakly filled higher orbitals of oxygen?',
#  'question: Whatare the electrostatic and magnetic force awritten as the sum of?',
#  'question: The analysis of stratigraphic sections such as drill cores is done by who?',
#  'question: What books did Bayle publish?',
#  "question: What was the Chinese name of Gou's calendar?",
#  'question: What do current ctenophores have that fossils found did not have?',
#  'question: What two member nations of the Holy Roman Empire received Huguenot refugees?',
#  'question: How much is the sieve method of gas production used?',
#  'question: Where is much of the work of the Scottish Parliament done?',
#  'question: In a steam turbine, what are rotors mounted on?',
#  'question: What do nuclear power plants heat to create electricity?',
#  'question: What do some encrypted broadcasts require to view?',
#  'question: What is the most critical resource in the analysis of computational problems associated with non-deterministic Turing machines?',
#  'question: Who is the university accredited by?',
#  "question: When was Warsaw's first stock exchange established?",
#  'question: When did the Plos Pathogens paper come out?',
#  'question: How many Africans were brought into the United States during the slave trade?',
#  'question: Which basin does the dust falls over into?',
#  'question: Where did Harold II die?',
#  'question: Complexity theory seeks to define the relationship between the scale of algorithms with respect to what other variable?',
#  'question: What did did article 34 discriminate against in Procureur du Roi v Dassonville?',
#  'question: What did the Court of Justice say Steymann was entitled to?',
#  'question: What is the name of one algorithm useful for conveniently testing the primality of large numbers?',
#  'question: From whom did the Huguenots in South Carolina purchase land from?',
#  'question: Ciliary rosettes pump water into what to control buoyancy?',
#  'question: What does oxygen the basis for in combustion?',
#  'question: In which continent besides Asia were major gains made by the British Empire in the late 19th century?',
#  'question: How long has Proportionality been recognized as one of the general principles of EU law?',
#  "question: Jean De Rely's illustrated French-language scriptures were first published in what city?",
#  'question: Why are the small lakes in the parks emptied before winter?',
#  'question: Imperialism and colonialism both assert a states dominance over what?',
#  'question: What is one reason a patient might choose an internet pharmacy?',
#  'question: The freedom to provide services under TFEU article 56 applies to who?',
#  'question: What element is found in most organic organisms?',
#  'question: In what treatment are nonconservative and conservative forces described?',
#  "question: What happens if a member doesn't vote the party line?",
#  'question: When did the last glacial end?',
#  'question: Where was France concentraing efforts?',
#  'question: What was the source of the mistake?',
#  'question: The area where Jacksonville currently sits has been inhabited for how many years?',
#  'question: When did colonial governors meet with General Edward Braddock about attack on the french?',
#  'question: What index is an indicator of the effects of taxes applied to social spending?',
#  'question: After its re-opening, which types of movies did the Tower Theatre show?',
#  'question: When does rain typically fall in Jacksonville?',
#  "question: What kind of force does not exist under Newton's third law?",
#  'question: What is the United States busiest commercial port?',
#  'question: Stratigraphers try to locate areas for what types of extraction?',
#  'question: Where is the famous rock the Rhine flows around?',
#  'question: Where is Brazil ranked globally in soybean production?',
#  'question: What are the factors that are contributing to the desire to have SR 99 improved to be of interstate standards?',
#  'question: What is another term for shortening the admission event?',
#  'question: One strategy of Islamization is to seize power by what methods?',
#  'question: When did a plague-ridden ship land in Norway?',
#  'question: Why is the need for acceptance of punishment needed?',
#  'question: What type of geologists give information about strain within the crystalline structure of the rocks?',
#  'question: Which genus is considered the "aunt" of ctenophores?',
#  "question: Which country's cars became more highly sought after as they were more fuel efficient?",
#  'question: In what part of the city did residents suffer from a lack of city services?',
#  'question: What does the electrolysis of water produce?',
#  'question: Who said Barton\'s investigation was "misguided and illegitimate"?',
#  'question: How many societal class divisions were in the plan Kublai rejected?',
#  'question: What German ruler invited Huguenot immigration?',
#  'question: What type of Turing machine is capable of multiple actions and extends into a variety of computational paths?',
#  'question: Can the President of the Council vote on important matters related to the European Central Bank?',
#  'question: What year did the university open a center in Hong Kong?',
#  'question: What is the United States at risk for because of the recession of 2008?',
#  'question: In addition to the traveling salesman problem, what is another example of a function problem?',
#  'question: What is one way in which graphs can be encoded?',
#  'question: What is the shortened name of the annual yacht race that takes place?',
#  'question: Who developed the lithium-ion battery?',
#  'question: What is the force equivalent of torque compared to angular momentum?',
#  'question: Which type of climate may have allowed the rainforest to spread across the continent?',
#  'question: How did the 2001 IPCC report compare to reality on temperature levels?',
#  'question: What group of people cannot be part of civil disobedience?',
#  'question: During which period did Jacksonville become a popular destination for the rich?',
#  'question: What public entity of learning is often target of civil disobedience?',
#  'question: By whom is European Law applied by?',
#  'question: How many customers does Sky UK Limited have as a pay-TV broadcaster as of 2015?',
#  'question: At what angle were the groups of pistons set in relation to one another in a 4-cylinder compound?',
#  "question: Dutch architect Janjaap Ruijssenaars's performative architecture 3D-printed building is scheduled to be built when?",
#  'question: What has having an EU Citizenship increased?',
#  'question: Which theory justifies imperialism in part?',
#  'question: The development of Terra Preta allowed for what to happen in the Amazon Forest?',
#  'question: What does motion at a constant velocity equal?',
#  "question: What was the purpose of Loudoun's troops at Fort Henry?",
#  'question: What does it mean when currencies are left to "float?"',
#  "question: Which country's invasion show the insecurity of the Middle East?",
#  'question: When did Pachauri resign as chair of the IPCC?',
#  'question: How can you protest against big companies in a non violent way?',
#  'question: Where does newly created wealth concentrate?',
#  'question: What does the 9 +3 pattern of cilia thought to do?',
#  'question: Who was famous for disobedience against a tax collector?',
#  'question: Humans in tropical environments were considered what?',
#  'question: How did user of Tymnet connect',
#  'question: When did French Republicans back building the French empire?',
#  'question: Where did Old Briton call home?',
#  'question: These books became a foundational text for what library?',
#  'question: In the United States, what is a usual turbine speed with 60 Hertz of power?',
#  'question: What long term agenda was the acts of plundering Muslim lands by the West?',
#  'question: What type of Delta is the Rhine-Meuse?',
#  'question: Le grand states that students studying civil disobedience will often run into grammatical niceties and what other problem?',
#  "question: What is Victoria's largest non-Christian religion?",
#  'question: What Fields Medal winning Mathematician is a faculty member at Harvard?',
#  'question: Along with road vehicles, locomotives and ships, on what vehicles were steam engines used during the Industrial Revolution?',
#  'question: In what part of the city did residents suffer from a lack of city services?',
#  'question: What is inequality associated with higher levels of?',
#  "question: What's the party's take on Muslim history?",
#  'question: Who was made Governor of Samarqand?',
#  'question: Who is the author of the book, "Knowledge and Decisions"?',
#  'question: A specific algorithm demonstrating T(n) represents what measure of time complexity?',
#  'question: Who was one French pro-reform Roman Catholic of the 15th century?',
#  'question: Who disliked the affiliate program?',
#  'question: What leader led the Dutch Revolt and wrote Apologie?',
#  'question: In what year was the agreement to allow the Saarland settlement reached?',
#  'question: What does the Presiding Officer try to achieve a balance of between speakers?',
#  'question: Prior to the arrival of the French, the area now known as Jacksonville was previously inhabited by what people?',
#  "question: What part do events in Victoria's economy play?",
#  'question: Who decides who gets to address the members of Parliament to share their thoughts on issues of faith?',
#  'question: What river is located in the vicinity of the school?',
#  'question: What were Huguenots who stayed in France eventually known as?',
#  'question: When did Mongke Khan die?',
#  'question: Sedimentary rock can be turned into which of the three types of rock?',
#  'question: Which two treaties provided more formal institutions of the European Union?',
#  'question: How did Celeron handle meeting with Old Briton?',
#  "question: How many horsepower was Watt's engine?",
#  'question: What is the translation of Siebengebirge?',
#  'question: What is the Rhine Gorge known for?',
#  'question: If 1 were to be considered as prime what would the sieve of Eratosthenes yield for all other numbers?',
#  'question: What is one main reason that civil disobedience is not recognized?',
#  'question: What is the goal of the capabilities approach?',
#  'question: What was the name of Theodore Roosevelt’s policy of imperialism?',
#  'question: What force acts on an object suspended on a spring scale in addition to gravity?',
#  'question: Antigens bind to what in order to elicit a response of the immune system?',
#  'question: Who notably improved the Savery water pump?',
#  'question: _____ Helps the biospher from UV.',
#  'question: According to reduction, if X and Y can be solved by the same algorithm then X performs what function in relationship to Y?',
#  'question: Levels of what things are used to determine emission factors?',
#  'question: When did OPEC start to readjust oil prices?',
#  'question: What is the height of the section that turns north?',
#  'question: In South Africa, along with privately governed schools, what schools are classified as independent?',
#  'question: Why should someone not commit a crime when they are protesting?',
#  'question: Stable and radioactive isotope studies provide insight into what?',
#  'question: What type of electric current is needed for electrolysis?',
#  'question: What percentage of New Zealand students attended private schools in April 2014?',
#  'question: What is something that is often torn up and included in sedimentary rock?',
#  'question: What vote on a bill takes place in Stage 3?',
#  'question: What is malum in se considerations?',
#  'question: What does the Islamic State lack from the international community?',
#  'question: What type of ratios are used in geochronologic and thermochronologic studies?',
#  'question: What device is used to treat various conditions such as carbon monoxide poisoning?',
#  ...]

# %%
df_val = pd.read_csv("/content/squad/val.csv")

# %%
df_val.head()
# Out:
#                          id  ...             text
# 0  57264d9edd62a815002e8101  ...               20
# 1  572a096e6aef0514001551e6  ...   bacteriophages
# 2  5706149552bb891400689880  ...           Chivas
# 3  56de1563cffd8e1900b4b5c4  ...     the Adriatic
# 4  572878942ca10214002da3a2  ...  political unity
#
# [5 rows x 5 columns]

# %%
len(outputs)
# Out:
# 10388

# %%
df_val.shape
# Out:
# (10388, 5)

# %%
df_val["new_questions"] = outputs

# %%
df_val.shape
# Out:
# (10388, 6)

# %%
df_val.head()
# Out:
#                          id  ...                                      new_questions
# 0  57264d9edd62a815002e8101  ...  question: How many gasoline stations in the Un...
# 1  572a096e6aef0514001551e6  ...  question: What is the restriction modification...
# 2  5706149552bb891400689880  ...  question: What team was suspended after the 20...
# 3  56de1563cffd8e1900b4b5c4  ...      question: What area is Dyrrachium located in?
# 4  572878942ca10214002da3a2  ...  question: What promoted trade between East and...
#
# [5 rows x 6 columns]

# %%
df_val.to_csv("final.csv")
